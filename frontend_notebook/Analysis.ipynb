# %%
import urllib.request, json
import requests
news_url = 'https://www.db.com/api/content/limit/400/offset/30/render/false/type/json/query/%20+((categories:adHocRelease%20categories:event1%20categories:mediaRelease%20categories:news%20categories:research)%20&&%20(categories:africa%20categories:americas1%20categories:asiapacific%20categories:europeexGermany%20categories:germany%20categories:middleEast%20categories:art%20categories:assetManagement%20categories:awards%20categories:capitalMarkets%20categories:careers%20categories:company1%20categories:corporateCitizenship%20categories:corporateProducts%20categories:cryptocurrencies%20categories:culture%20categories:digitalBankingServices%20categories:digitalisation%20categories:diversity%20categories:education%20categories:employeeEngagement%20categories:entrepreneurship%20categories:financialResults%20categories:history%20categories:investmentBanking%20categories:managementLeadership%20categories:personnelAnnouncements%20categories:privateProducts%20categories:research3%20categories:sports%20categories:strategy%20categories:sustainability%20categories:wealth))%20%20+conhost:8e29bc28-e0f6-40f1-930a-6258631a0985%20+languageId:1%20+deleted:false%20/orderby/C03News.publishDate%20desc'
backend_api='https://gee16-22-team12.ew.r.appspot.com/api/text'
with urllib.request.urlopen(news_url) as url:
   data = json.load(url)
for news in data['contentlets']:
    if news.get('richText'):
        print(requests.post(backend_api, data={'text':news['richText']}))
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [500]>
# <Response [200]>
# <Response [200]>
# <Response [500]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [500]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [500]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>

# %%
requests.get(backend_api).json()
# Out:
# {'4797240753258496': {'text': '<div>\n<div><span> </span>\n<p><img alt="Christiana Riley HERoes" src="/files/news/images/Christiana_Riley_crop2_Yahoo.jpg" />The HERoes 100 Women Executives list celebrates women who are leading by example and driving change to increase gender diversity in the workplace. Americas CEO, Christiana Riley not only made the list, but also earned the number 5 spot out of 100. The HERoes judging panel scored each nominee on the influence of their role, their impact on women inside and outside the workplace, and their business achievements.<br /> <br /> Christiana shares the spotlight with other influential executives such as Jennifer Jackson, President, Capital One Canada; Ann Cairns, Executive Vice-Chairman, Mastercard; June Felix, CEO, IG Group; and Masami Katakura, Chairwoman &amp; CEO, EY ShinNihon.<br /> <br /> Serving as the first woman regional CEO at Deutsche Bank in our 150 year history, Christiana has committed to driving inclusion in the workplace and has set gender equality objectives for the region. This is not the first such accolade for Christiana. Earlier this year, Christiana was also named by Financial Times one of the &ldquo;Ten people set to shape Wall Street in 2020.&rdquo;&nbsp;</p>\n</div>\n</div>',
#   'timestamp': '2022-09-15 19:19:38.760508+00:00',
#   'sentiment': 'positive',
#   'entities': ['women',
#    'Christiana',
#    'list',
#    'workplace',
#    'change',
#    'gender diversity',
#    'example',
#    'HERoes 100 Women Executives',
#    'Felix',
#    'Christiana Riley',
#    'women',
#    'Americas',
#    'spot',
#    'spotlight',
#    'executives',
#    'workplace',
#    'business achievements',
#    'President',
#    'impact',
#    'influence',
#    'role',
#    'nominee',
#    'HERoes',
#    'Christiana',
#    'Chairwoman',
#    'Executive Vice-Chairman',
#    'accolade',
#    'panel',
#    'workplace',
#    'region',
#    'gender equality objectives',
#    'one',
#    'Capital One Canada',
#    'Jennifer Jackson',
#    'Ann Cairns',
#    'Mastercard',
#    'IG Group',
#    'Masami Katakura',
#    'EY ShinNihon',
#    'people',
#    'CEO',
#    'woman',
#    'inclusion',
#    'history',
#    'Financial Times',
#    'Wall Street',
#    'Deutsche Bank',
#    '2020',
#    'One',
#    '5',
#    'one',
#    '100',
#    '100',
#    '2020',
#    '150'],
#   'topics': ['/People & Society']},
#  '4797561198084096': {'text': '<div>\n<div><span> </span>\n<p>Deutsche Bank, together with Italy&rsquo;s Banco BPM and other syndicate banks, on Monday announced a loan of 27.5 million euros to Brescia Group&rsquo;s Ambrosi SpA, a leading Italian company which specialises in the production and ageing of Grana Padano and Parmigiano Reggiano DOP cheeses.</p>\n<p>In a first for Deutsche Bank in Italy, the 5-year loan is secured by Ambrosi SpA&rsquo;s own inventory of parmesan cheese, which today in Italy has become a more &ldquo;liquid asset&rdquo; than property.</p>\n<blockquote class="quote-box">After a maturing process that lasts at least two years, premium Italian cheeses such as the Grana Padano and Parmigiano Reggiano DOP fetch prices of between 550 and 740 euros per wheel on the open market.</blockquote>\n<p>The proceeds of the loan will be utilised to enhance Ambrosi SpA&rsquo;s ability to export world class, Italian made cheeses around the world, starting from the new facility built to hold a total of 120,000 cheese wheels, increasing the company&rsquo;s cheese production capacity by 20 percent.</p>\n<p>Founded in 1942, with its headquarters in the Lombardy province of Brescia, Ambrosi SpA is one of the leading Italian producers and distributors of premium traditional Italian cheeses. In 2019, the company reported consolidated revenues of 440 million euros, with a 46 percent share of the total export market. Ambrosi products are marketed in 60 countries worldwide.</p>\n<p>Germany is the first and largest m',
#   'timestamp': '2022-09-15 19:19:36.287406+00:00',
#   'sentiment': 'positive',
#   'entities': ['Ambrosi SpA',
#    'Italian',
#    'company',
#    'loan',
#    'Deutsche Bank',
#    'Italy',
#    'DOP cheeses',
#    'syndicate banks',
#    'process',
#    'production',
#    'ageing',
#    'Brescia Group',
#    'Parmigiano Reggiano',
#    'Banco BPM',
#    'Grana Padano',
#    'parmesan cheese',
#    'bank',
#    'first',
#    'loan',
#    'revenues',
#    'asset',
#    'cheeses',
#    'cheeses',
#    'customers',
#    'inventory',
#    'property',
#    'market',
#    'products',
#    'cheeses',
#    'company',
#    'total',
#    'commitment',
#    'open market',
#    'loan',
#    'producers',
#    'export market',
#    'world',
#    'cheese wheels',
#    'wheel',
#    'proceeds',
#    'group',
#    'foreign bank',
#    'facility',
#    'cheese production capacity',
#    'province',
#    'headquarters',
#    'prices',
#    'ability',
#    'world class',
#    'companies',
#    'company',
#    'distributors',
#    'share',
#    'countries',
#    'exports',
#    'Ambrosi',
#    'all',
#    'sales',
#    'supermarkets',
#    'relationship',
#    'coronavirus crisis',
#    'companies',
#    'Brescia',
#    'Germany',
#    'thanks',
#    'Lombardy',
#    'commitment',
#    'business',
#    'phases',
#    'announcement',
#    'emergency',
#    'some',
#    'group',
#    'proof',
#    'Covid',
#    'branches',
#    'catering activities',
#    'restrictions',
#    'turnover',
#    'increase',
#    'Covid-19',
#    'United Kingdom',
#    'France',
#    'US',
#    '1942',
#    '2019',
#    '2020',
#    '27.5 million euros',
#    '740 euros',
#    '440 million euros',
#    '46',
#    '5',
#    '2019',
#    '440 million',
#    '60',
#    '27.5 million',
#    '120,000',
#    '2020',
#    '20',
#    '10',
#    'two',
#    '19',
#    '740',
#    'one',
#    '1942',
#    'six',
#    '19',
#    '550'],
#   'topics': ['/Finance', '/Business & Industrial']},
#  '4808284053700608': {'text': '<p>Deutsche Bank (XETRA: DBKGn.DB / NYSE: DB) has announced&nbsp;that it has joined the Net Zero Banking Alliance [NZBA] which was launched today.&nbsp;</p>\n<p>An initial group of 43 banks from 23 countries have joined the NZBA, each committing to align the operational and attributable emissions from their portfolios with pathways to net-zero by 2050 or sooner.</p>\n<p>The NZBA has been convened by the United Nations Environment Programme Finance Initiative as part of the Glasgow Financial Alliance for Net Zero (GFANZ). The GFNAZ brings together existing net zero finance initiatives into a sector-wide strategic forum. It will work to mobilise the trillions of euros necessary to build a global zero emissions economy and deliver the goals of the Paris Agreement.</p>\n<p>Christian Sewing, Deutsche Bank CEO, commented: &nbsp;&ldquo;Banks will play a crucial role in the fight against climate change, and the creation of the NZBA is an important step forward to developing coordinated, accelerated action. We are proud to be a founding member of the NZBA and to commit to making our portfolio net zero carbon by 2050 at the latest. We look forward to playing an active role in the work of the alliance.&rdquo;</p>\n<p>Deutsche Bank made sustainability a strategic priority in 2019, and this commitment is one of many actions taken by the bank since then to further develop sustainability within its own operations and those of its clients.</p>\n<p>In May 2020, Deutsche Bank set itself the target',
#   'timestamp': '2022-09-15 19:16:17.078551+00:00',
#   'sentiment': 'positive',
#   'entities': ['Deutsche Bank',
#    'statements',
#    'Net Zero Banking Alliance',
#    'Christian Sewing',
#    'NZBA',
#    'GFNAZ',
#    'group',
#    'banks',
#    'creation',
#    'DB',
#    'DBKGn.DB',
#    'commitment',
#    'portfolios',
#    'NYSE',
#    'XETRA',
#    'emissions',
#    'countries',
#    'part',
#    'finance initiatives',
#    'pathways',
#    'Glasgow Financial Alliance for Net Zero',
#    'Banks',
#    'factors',
#    'United Nations Environment Programme Finance Initiative',
#    'economy',
#    'bank',
#    'portfolio net',
#    'bank',
#    'bond',
#    'action',
#    'member',
#    'carbon',
#    'emissions',
#    'goals',
#    'climate change',
#    'number',
#    'forum',
#    'trillions',
#    'fight',
#    'CEO',
#    'latest',
#    'conditions',
#    'financing',
#    'investment',
#    'lending portfolios',
#    'signatory',
#    'statements',
#    'bond',
#    'bonds',
#    'alliance',
#    'sustainability',
#    'sustainability',
#    'actions',
#    'target',
#    'target',
#    'event',
#    'targets',
#    'statement',
#    'products',
#    'hedging transaction',
#    'Email',
#    'sector',
#    'Email',
#    'Email',
#    'clients',
#    'goal',
#    'arranger',
#    'progress',
#    'governance',
#    'information',
#    'ESG',
#    'opinion',
#    'hedge framework',
#    'issuer',
#    'conference',
#    'Paris Agreement',
#    'work',
#    'priority',
#    'operations',
#    'investor clients',
#    'factors',
#    'portion',
#    'portion',
#    'risks',
#    'space',
#    'Media Relations',
#    'management',
#    'role',
#    'role',
#    'details',
#    'events',
#    'information',
#    'any',
#    'markets',
#    'assumptions',
#    'Sustainability Deep Dive',
#    'Commitment on Climate Action',
#    'Germany',
#    'obligation',
#    'light',
#    'nature',
#    'uncertainties',
#    'results',
#    'elsewhere',
#    'banking',
#    'investment banking',
#    'banking',
#    'risks',
#    'Charlie Olivier',
#    'assets',
#    'initiatives',
#    'US',
#    'DB Access',
#    'German',
#    'DWS',
#    'trading counterparties',
#    'detail',
#    'facts',
#    'Tim-Oliver Ambrosius',
#    'Dylan Riddle',
#    'statements',
#    'DB Research',
#    'methods',
#    'revenues',
#    'procedures',
#    'development',
#    'risk management policies',
#    'asset prices',
#    'market volatility',
#    'filings',
#    'reliability',
#    'defaults',
#    'borrowers',
#    'implementation',
#    'request',
#    'document',
#    'Copies',
#    'release',
#    'investors',
#    'Risk Factors',
#    'asset',
#    'wealth management',
#    'U.S. Securities and Exchange Commission',
#    'governments',
#    'corporate',
#    'corporations',
#    'lending',
#    'transaction',
#    'individuals',
#    'services',
#    'companies',
#    'network',
#    'roots',
#    'beliefs',
#    'expectations',
#    'projections',
#    'plans',
#    'estimates',
#    'products',
#    'European',
#    '+44 7917151627',
#    '2050',
#    '2050',
#    '2019',
#    'May 2020',
#    '2025',
#    '2020',
#    'June 2020',
#    'March 2021',
#    '2021',
#    'March 2021',
#    'June 2020',
#    'May 2021',
#    '21 March 2021',
#    '200 billion euros',
#    '46 billion euros',
#    '20 billion euro',
#    '7917151627',
#    '2020',
#    'zero',
#    '2021',
#    '43',
#    '2021',
#    '2020',
#    '46 billion',
#    '2021',
#    'zero',
#    'zero',
#    '2050',
#    'zero',
#    '200 billion',
#    'one',
#    'Zero',
#    'Zero',
#    '2020',
#    '2021',
#    '+44',
#    '2019',
#    '23',
#    '2025',
#    '2021',
#    '2020',
#    '2050',
#    '5',
#    '20 billion',
#    '20',
#    '21'],
#   'topics': ['/Finance/Banking']},
#  '4809359741681664': {'text': '<div>\n<div><span> </span>\n<p>Deutsche Bank today announced that it has become the first European bank to be approved for the State Administration of Foreign Exchange (SAFE)&rsquo;s Pilot Scheme for Facilitation of Foreign Exchange Receipts and Payments for Trade, which aims to simplify and improve foreign currency payments for cross-border trades.</p>\n<p>Under the scheme, eligible clients of Deutsche Bank China (Shanghai Branch) will be exempt from providing supporting documents for foreign currency trade payment up front, allowing a straight-through payment processing upon the client&rsquo;s e-banking instruction. Compared with the traditional payment procedure, this cuts the foreign currency payment process time to just a few minutes from days. The bank has completed its first foreign currency payment under the pilot scheme for global automotive technology company Aptiv on September 30.</p>\n<p>Jerry Chen, Asia Pacific Chief Financial Officer of Aptiv, said: &ldquo;Cross-border foreign exchange payments have been a lengthy process for corporates. With Deutsche Bank&rsquo;s pilot scheme services, we see the direct benefits with faster and easier payments. As Aptiv&rsquo;s banking partner, Deutsche Bank has provided us with a tailor-made pilot solution, which improved the overall process throughout the payment cycle and it is testament to Deutsche Bank&rsquo;s professionalism and commitment.&rdquo;</p>\n<p>Alvin Ho, Deutsche Bank China Head of Corporate Cash Management, said: ',
#   'timestamp': '2022-09-15 19:19:32.024764+00:00',
#   'sentiment': 'positive',
#   'entities': ['Deutsche Bank',
#    'State Administration of Foreign Exchange',
#    'bank',
#    'currency payments',
#    'trades',
#    'Payments for Trade',
#    'bank',
#    'Pilot Scheme for Facilitation of Foreign Exchange Receipts',
#    'Aptiv',
#    'clients',
#    'scheme',
#    'testimony',
#    'European',
#    'currency payment',
#    'foreign exchange payments',
#    'currency trade payment',
#    'currency payment',
#    'China',
#    'Shanghai Branch',
#    'banks',
#    'investment banking',
#    'retail banking',
#    'transaction banking',
#    'payment processing',
#    'payment procedure',
#    'pilot scheme',
#    'Alvin Ho',
#    'Jerry Chen',
#    'client',
#    'payments',
#    'Deutsche Bank Securities Inc.',
#    'front',
#    'instruction',
#    'documents',
#    'one',
#    'process',
#    'currency trade payments pilot scheme',
#    'corporates',
#    'pilot solution',
#    'clients',
#    'clients',
#    'Lending',
#    'process',
#    'trade account pilot solutions',
#    'payment solutions',
#    'commitment',
#    'commitment',
#    'pilot scheme services',
#    'banking',
#    'authority',
#    'authorization',
#    'benefits',
#    'services',
#    'wealth management',
#    'regulation',
#    'regulation',
#    'regulation',
#    'capital account',
#    'professionalism',
#    'payment cycle',
#    'market expertise',
#    'banking partner',
#    'information technology capabilities',
#    'asset',
#    'Prudential Regulation Authority',
#    'Financial Conduct Authority',
#    'Asia Pacific',
#    'products',
#    'DB',
#    'Banking Law',
#    'extent',
#    'Corporate Cash Management',
#    'Shanghai',
#    'Details',
#    'BaFin - Federal Financial Supervisory Authority',
#    'broker-dealer affiliates',
#    'banking affiliates',
#    'investment banking activities',
#    'Securities',
#    'activities',
#    'request',
#    'member',
#    'C',
#    'Copyright',
#    'German',
#    'United States',
#    'investors',
#    'corporations',
#    'affiliates',
#    'presence',
#    'individuals',
#    'governments',
#    'businesses',
#    'position',
#    'subsidiaries',
#    'NYSE',
#    'SIPC',
#    'NASD',
#    'press release',
#    'Germany',
#    'Europe',
#    'Americas',
#    'September 30',
#    '2020',
#    'one',
#    '30',
#    'one',
#    '2020'],
#   'topics': ['/Finance/Banking']},
#  '4813393923932160': {'text': "<p>The New Year saw unprecedented activity in Asian debt capital markets with record levels of Asian currency bond issuance from regional governments and companies, as they tried to leverage low interest rates to help raise funds for recovery as well as growth to new markets. This included the Republic of Indonesia&rsquo;s&nbsp;3 billion US dollar/ 1 billion euro 4-tranche sovereign issuance.</p>\n<p>&nbsp;The combination of investors keen to put money to work, coupled with clients looking to extend debt maturities and capture the first available funding window, led to the landmark volume of issuance according to Deutsche Bank&rsquo;s APAC head of Capital Markets, Haitham Ghattas.</p>\n<p>&ldquo;What&rsquo;s driving the volume is that rates are creating a very opportunistic market for issuers locking in very good long-term funding,&rdquo; Deutsche Bank's APAC Head of debt syndicate &amp;&nbsp;North Asia Debt</p>\n<p>As issuers look to refinance their existing debt at longer maturities, Tsui sees a strong demand from investors who have a strong appetite for longer-dated debt.&nbsp;Reuters reported that&nbsp;Asia&rsquo;s corporate credits were a popular trade recommendation for 2021 from,&nbsp;as they were paying better than comparably risky debt in Europe and the United States.&nbsp;</p>\n<p>A combination of factors including&nbsp;the vaccine rollout, fiscal stimulus and the US election outcome paved the way for institutional investors to reallocate capital to Asia, and tap the d",
#   'timestamp': '2022-09-15 19:17:43.542409+00:00',
#   'sentiment': 'positive',
#   'entities': ['governments',
#    'currency bond issuance',
#    'debt capital markets',
#    'interest rates',
#    'recovery',
#    'funds',
#    'record levels',
#    'activity',
#    'companies',
#    'Asian',
#    'The New Year',
#    'markets',
#    'issuers',
#    'combination',
#    'Deutsche Bank',
#    'growth',
#    'investors',
#    'issuance',
#    'Reuters',
#    'debt maturities',
#    'investors',
#    'clients',
#    'United States',
#    'Debt',
#    'debt',
#    'money',
#    'debt',
#    'market',
#    'issuers',
#    'Capital Markets',
#    'issuance',
#    'funding',
#    'head',
#    'rates',
#    'trade recommendation',
#    'maturities',
#    'landmark volume',
#    'volume',
#    'Vishal Goenka',
#    'debt syndicate',
#    'funding window',
#    'demand',
#    'appetite',
#    'Republic of Indonesia',
#    'rates',
#    'APAC',
#    'dollar',
#    'currencies',
#    'region',
#    'bond yields',
#    'APAC Head',
#    'weakening',
#    'outlook',
#    'credit spreads',
#    'team',
#    'Tsui',
#    'Haitham Ghattas',
#    'region',
#    'clients',
#    'combination',
#    'credits',
#    'credit sales',
#    'debt',
#    'capital',
#    'APAC Capital Markets',
#    'ICG APAC',
#    'offerings',
#    'differential',
#    'way',
#    'election outcome',
#    'stimulus',
#    'factors',
#    'investors',
#    'Europe',
#    'vaccine rollout',
#    '2021',
#    '3 billion US dollar',
#    '1 billion euro',
#    'USD 12bn',
#    '4',
#    '12bn',
#    '1 billion',
#    '3 billion',
#    '14',
#    '2021'],
#   'topics': ['/Finance']},
#  '4816505157976064': {'text': '<p>Ladies and gentlemen,</p>\n<p>it is a pleasure for me to speak at this banking summit again. This year, for the first time, I am speaking to you from London, where many of our largest institutional clients have gathered together again at last. This means we&rsquo;re returning to a little bit of normality. And it&rsquo;s an indication that we are gradually emerging from the pandemic.</p>\n<p>You can interpret the fact that I no longer want to talk about how we can get out of this crisis as quickly as possible as another indication of that. Instead, I want to look far into the distance. What are the big trends and factors that will shape the banking industry in the next decade? And what do we need to do to emerge from this upheaval as winners?</p>\n<p>There is a consensus, ladies and gentlemen, that our economy must become more digital and more sustainable. This transformation, driven by technology, will be just as fundamental in nature as the first industrial revolution more than two centuries ago. Back then, humanity began burning carbon on a large scale. In this century, it will have to largely stop doing that if we want to avoid a catastrophe. Leading scientists agree on that.</p>\n<p>At the same time, the stakes for Europe are high.</p>\n<p>This decade will decide who will dominate the global economy in the 21st century. And Europe will have to pull out all the stops to avoid being one of the losers.</p>\n<p>Yet we have already fallen behind in the past 20 years. In 2000, 41',
#   'timestamp': '2022-09-15 19:14:13.736329+00:00',
#   'sentiment': 'positive',
#   'entities': ['Europe',
#    'economy',
#    'pleasure',
#    'sector',
#    'indication',
#    'securitisation market',
#    'economy',
#    'London',
#    'customers',
#    'Ladies',
#    'gentlemen',
#    'trends',
#    'sustainability',
#    'US',
#    'challenge',
#    'consensus',
#    'banks',
#    'transformation',
#    'industry',
#    'banking industry',
#    'progress',
#    'struggle',
#    'capital regulations',
#    'time',
#    'ladies',
#    'gentlemen',
#    'fact',
#    'factors',
#    'technology',
#    'imbalance',
#    'many',
#    'crisis',
#    'indication',
#    'winners',
#    'scale',
#    'humanity',
#    'principle',
#    'banks',
#    'banking summit',
#    'clients',
#    'normality',
#    'bit',
#    'pandemic',
#    'distance',
#    'capital',
#    'upheaval',
#    'revolution',
#    'nature',
#    'carbon',
#    'catastrophe',
#    'scientists',
#    'stakes',
#    'course',
#    'industry',
#    'banks',
#    'banks',
#    'banking',
#    'banking',
#    'banks',
#    'capital market',
#    'banks',
#    'banks',
#    'one',
#    'economy',
#    'economy',
#    'banks',
#    'banks',
#    'banking',
#    'banks',
#    'core bank',
#    'banks',
#    'sector',
#    'sector',
#    'capital market',
#    'banking',
#    'banks',
#    'banks',
#    'banks',
#    'banks',
#    'banks',
#    'insurers',
#    'one',
#    'companies',
#    'companies',
#    'Bank of America',
#    'fact',
#    'whole',
#    'whole',
#    'credit markets',
#    'market',
#    'world',
#    'stock market value',
#    'value',
#    'economies',
#    'correlation',
#    'economy',
#    'regulation',
#    'banks',
#    'course',
#    'market',
#    'losers',
#    'proposition',
#    'location advantages',
#    'economy',
#    'condition',
#    'sector',
#    'stops',
#    'Deutsche Bank',
#    'millennium',
#    'decline',
#    'order',
#    'economy',
#    'regulation',
#    'investments',
#    'competition',
#    'interests',
#    'interests',
#    'interest',
#    'whole',
#    'progress',
#    'structures',
#    'consolidation',
#    'colleagues',
#    'investors',
#    'lever',
#    'bond market',
#    'capital markets union',
#    'world',
#    'importance',
#    'world',
#    'stock market value',
#    'return',
#    'return',
#    'conditions',
#    'Germany',
#    'advice',
#    'bank',
#    'banking',
#    'bank',
#    'mistake',
#    'business',
#    'scale',
#    'techs',
#    'returns',
#    'size',
#    'cost pressure',
#    'face',
#    'services',
#    'capital markets union',
#    'profitability',
#    'crisis',
#    'profit',
#    'business areas',
#    'propositions',
#    'importance',
#    'level',
#    'playing field',
#    'financing',
#    'services',
#    'preserve',
#    'face',
#    'loans',
#    'course',
#    'path',
#    'business',
#    'companies',
#    'deal',
#    'roots',
#    'efficiency gains',
#    'capital market deficit',
#    'leader',
#    'Sustainability',
#    'experience',
#    'discrepancies',
#    'track',
#    'institutions',
#    'point',
#    'equity',
#    'result',
#    'line',
#    'target',
#    'goals',
#    'players',
#    'headquarters',
#    'investments',
#    'Sustainability',
#    'investors',
#    'consolidation',
#    'market share',
#    'whole',
#    'gentlemen',
#    'borders',
#    'barriers',
#    'room',
#    'bank balance sheets',
#    'manoeuvre',
#    'non-banks',
#    'groups',
#    'interest rates',
#    'path',
#    'Ladies',
#    'China',
#    'technology',
#    'change',
#    'transactions',
#    'advice',
#    'transformation',
#    'importance',
#    'structure',
#    'climate change',
#    'JP Morgan',
#    'economy',
#    'use',
#    'business',
#    'conditions',
#    'areas',
#    'bonds',
#    'loans',
#    'governance',
#    'risk management',
#    'dialogue',
#    'topic',
#    'leap',
#    'business field',
#    'banking',
#    'prospects',
#    'regulation',
#    'banks',
#    'industry',
#    'more',
#    'industries',
#    'standards',
#    'validation',
#    'demand',
#    'lot',
#    'each',
#    'divisions',
#    'potential',
#    'banking sector',
#    'sustainability',
#    'dialogue',
#    'increase',
#    'twenties',
#    'course',
#    'conditions',
#    'Ladies',
#    'gentlemen',
#    'advantage',
#    'asset',
#    'advice',
#    'benchmark',
#    'culture',
#    'leadership culture',
#    'people',
#    'management',
#    'challenges',
#    'Basel IV',
#    'sectors',
#    'banking sector',
#    'network',
#    'society',
#    'purpose',
#    'focus',
#    'work',
#    'teams',
#    'view',
#    'strategy',
#    'attitude',
#    'regulation',
#    'regulation',
#    'regulation',
#    'people',
#    'constellations',
#    'competition',
#    'growth topic',
#    'consolidation',
#    'sustainability',
#    'investments',
#    'opportunity',
#    'duty',
#    'climate change',
#    'financing volume',
#    'losers',
#    'winners',
#    'humanity',
#    'governance',
#    'share',
#    'banking system',
#    'elsewhere',
#    'No one',
#    'stability',
#    'way',
#    'criteria',
#    'estimates',
#    'calculations',
#    'ESG',
#    'Autonomous',
#    '2000',
#    '2015',
#    '2022',
#    '2050',
#    '2.8 billion euros',
#    '3.4 billion euros',
#    '20',
#    'one',
#    '3.4 billion',
#    '100',
#    '6.5',
#    '21',
#    'one',
#    '25',
#    '18',
#    'one',
#    '25',
#    '41',
#    '2015',
#    'six',
#    'one',
#    'two',
#    '2000',
#    '2.8 billion',
#    '9.3',
#    '2050',
#    'two',
#    'one',
#    '15',
#    '15',
#    'one',
#    'one',
#    '2022',
#    'three'],
#   'topics': ['/Finance', '/Business & Industrial']},
#  '4816817549737984': {'text': '<p>After two months, 43 applications, six finalists and one virtual pitch: Nuggets has emerged as the winner of the 2020 Female FinTech Competition.</p>\n<p>The UK-based e-commerce payments and ID platform allows users to store their personal and payment details securely in the blockchain, so it is never shared online. According to Nuggets: &ldquo;That means no more data breaches &ndash; because companies don&rsquo;t have to store your data. So you can use services and make payments without worrying about your privacy and security.&rdquo;</p>\n<p>The competition, run by Deutsche Bank, Atos, Google Cloud and TechQuartier, invites FinTechs with a female founder or female(s) in the top management groups to pitch their business case. The winner earns a place on Atos&rsquo; FinTech programme, while the remaining finalists are able to access and benefit from Deutsche Bank and Google Innovation resources.</p>\n<p>Deutsche Bank judge Luc M&eacute;riochaud said: &ldquo;All six finalists delivered really compelling pitches, and we had a tough time judging. In the end, we had to agree on which one had the strongest business case at this moment in time, but I am looking forward to seeing how they all develop as I am convinced each has the potential to succeed.&rdquo;</p>\n<p>The competition aims to promote gender diversity in the FinTech space. A recent study from Deloitte found that only 7% of finance-based startup founders were women, and that this group is still being denied equal access',
#   'timestamp': '2022-09-15 19:19:09.438213+00:00',
#   'sentiment': 'positive',
#   'entities': ['Deutsche Bank',
#    'Luc Mériochaud',
#    'finalists',
#    'applications',
#    'blockchain',
#    'users',
#    'Nuggets',
#    'e-commerce payments',
#    'pitch',
#    'winner',
#    'Female FinTech Competition',
#    'payment',
#    'female(s)',
#    'details',
#    'ID platform',
#    'data breaches',
#    'winner',
#    'Atos',
#    'competition',
#    'finalists',
#    'women',
#    'competition',
#    'companies',
#    'FinTechs',
#    'services',
#    'data',
#    'founder',
#    'business case',
#    'management groups',
#    'study',
#    'UK',
#    'access',
#    'study',
#    'security',
#    'privacy',
#    'payments',
#    'finalists',
#    'companies',
#    'Gender diversity',
#    'women',
#    'gender diversity',
#    'women',
#    'each',
#    'group',
#    'startup founders',
#    'pitches',
#    'business case',
#    'plenty',
#    'potential',
#    'space',
#    'place',
#    'programme',
#    'benefit',
#    'resources',
#    'TechQuartier',
#    'Google Cloud',
#    'end',
#    'opportunities',
#    'funding',
#    'sector',
#    'population',
#    'gender diversity results',
#    'evidence',
#    'Judges',
#    'investment banking',
#    'banking',
#    'banking',
#    'France',
#    'relative',
#    'companies',
#    'Google Innovation',
#    'corporate',
#    'services',
#    'corporations',
#    'Deloitte',
#    'investors',
#    'wealth management',
#    'network',
#    '7%',
#    'Cloud Germany',
#    'Google',
#    'lending',
#    'governments',
#    'transaction',
#    'individuals',
#    'asset',
#    'roots',
#    'Global Head of Innovation Network',
#    'Head of Innovation Products',
#    'products',
#    'finalists',
#    'Finalists',
#    'Germany',
#    'Italy',
#    'Serena Torielli -- Virtual B',
#    'Annie Guo -- Silkpay',
#    'USA',
#    'Nerissa Naidu-- Axil',
#    'Corporate Venture Capital',
#    'AtoS Central Europe',
#    'HRD',
#    'Ozlum Yavus',
#    'MD',
#    'Annette Maier',
#    'Lucas Schmitt',
#    'competition',
#    'products',
#    'services',
#    'judges',
#    'hope',
#    'women',
#    'ideas',
#    'market',
#    'levels',
#    'role models',
#    'list',
#    'Tech Quartier',
#    'European',
#    'Seema Khinda Johnson -- Nuggets',
#    'Franca Perin -- IMPACTIN',
#    'Iwona Pawlak',
#    'Smart Forest',
#    'Poland',
#    'talent',
#    '2020',
#    '2019',
#    '7',
#    'six',
#    '1.3',
#    '2020',
#    '2019',
#    'two',
#    'six',
#    '43',
#    'one',
#    'one'],
#   'topics': ['/Business & Industrial']},
#  '4819281653006336': {'text': '<p>Deutsche Bank is supporting India&rsquo;s micro, small and medium enterprises (MSME) through the pandemic by extending over 12 billion Indian rupees (~138 million euros) of credit to more than 2,000 clients.</p>\n<p>The loans are part of the Government of India&rsquo;s Emergency Credit Line Guarantee Scheme (ECLGS) for MSMEs, launched in May 2020, and are provided in the form of a working capital term loan, backed by a 100 percent sovereign credit guarantee from the government.</p>\n<p>Clients benefit from a 12-month moratorium on the principal amount (repaying interest only) and start paying back the loan in equated installments over 36 months, after this relief period is over.</p>\n<p>Cash flows in India&rsquo;s MSME sector have been severely impacted by the COVID-19 pandemic because of reduced demand for their goods and services, coupled with disruption in supply chains.</p>\n<p>This relief package, which is part of the government&rsquo;s Atmanirbhar Bharat (Self-Reliant India) initiative, is expected to help the ailing sector meet its operational liabilities and restart businesses.</p>\n<p>&ldquo;It is in times such as this that our clients need us the most and I am glad that we were part of the solution,&rdquo; said Amit Bhatia, Head of International Private Bank, India. &ldquo;We put the clients at the core of our efforts and left no stone unturned to help them through the difficult times.&rdquo;</p>\n<p>The road to this solution was not easy. The new offering came with h',
#   'timestamp': '2022-09-15 19:19:03.621327+00:00',
#   'sentiment': 'positive',
#   'entities': ['Emergency Credit Line Guarantee Scheme',
#    'MSME',
#    'relief package',
#    'clients',
#    'credit',
#    'Deutsche Bank',
#    'pandemic',
#    'Government of India',
#    'sector',
#    'clients',
#    'part',
#    'Indian',
#    'loans',
#    'Cash flows',
#    'project effort',
#    'Amit Bhatia',
#    'Clients',
#    'government',
#    'term loan',
#    'credit guarantee',
#    'form',
#    'moratorium',
#    "Daryl D'Souza",
#    'government',
#    'clients',
#    'loan',
#    'times',
#    'part',
#    'interest',
#    'pandemic',
#    'sector',
#    'solution',
#    'goods',
#    'supply chains',
#    'disruption',
#    'demand',
#    'services',
#    'initiative',
#    'liabilities',
#    'ECLGS',
#    'amount',
#    'installments',
#    'businesses',
#    'scheme',
#    'Business',
#    'most',
#    'Lending',
#    'products',
#    'department',
#    'tandem',
#    'Sales',
#    'government',
#    'Head of International Private Bank',
#    'Atmanirbhar Bharat',
#    'COVID',
#    'people',
#    'country',
#    'Links',
#    'times',
#    'Risk',
#    'offering',
#    'efforts',
#    'solution',
#    'road',
#    'core',
#    'system changes',
#    'hurdles',
#    'processing requirements',
#    'documentation protocols',
#    'stone',
#    'May 2020',
#    'October 31',
#    'November 30',
#    '12 billion Indian rupees',
#    '138 million euros',
#    '63 million',
#    '19',
#    '2,000',
#    '2020',
#    '12',
#    '110 million',
#    '100',
#    '31',
#    '30',
#    '36',
#    '138 million',
#    '12 billion'],
#   'topics': ['/Finance/Banking']},
#  '4822599985004544': {'text': '<div><img alt="Christian Sewing, Chief Executive Officer: &ldquo;In a challenging environment we grew revenues and continued to reduce costs, and we&rsquo;re fully on track to meet all our targets.&rdquo;" src="https://www.db.com/files/news/images/2_EN_Sewing.PNG?language_id=1" width="658" height="312" /></div>\n<h3>2nd-quarter profit despite restructuring and rise in credit loss provisions</h3>\n<ul>\n<li>Group pre-tax profit of 158 million euros, versus pre-tax loss of 946 million euros in 2nd quarter of 2019</li>\n<li>Net profit of 61 million euros, versus net loss of 3.1 billion euros in the prior year quarter which included transformation-related effects</li>\n<li>Provision for credit losses of 761 million euros, consistent with management expectations; re-affirming full year guidance of 35-45 basis points of loans</li>\n</ul>\n<h3>Core Bank earnings momentum in the quarter</h3>\n<ul>\n<li>Pre-tax profit of 753 million euros, versus loss in prior year quarter</li>\n<li>Net profit of 489 million euros, post-tax return on tangible equity of 3.4%</li>\n</ul>\n<h3>Revenue growth year on year</h3>\n<ul>\n<li>Group net revenues up 1% to 6.3 billion euros despite exit of Equities</li>\n<li>Core Bank net revenues up 6% to 6.4 billion euros, up 8% to 6.3 billion euros ex-specific items</li>\n<li>Investment Bank net revenues up 46%, up 52% ex-specific items</li>\n</ul>\n<h3>Sustained progress on costs</h3>\n<ul>\n<li>Noninterest expenses down 23% year-on-year to 5.4 billion euros</li>\n<li>Adjusted c',
#   'timestamp': '2022-09-15 19:20:22.288707+00:00',
#   'sentiment': 'positive',
#   'entities': ['loss',
#    'profit',
#    'credit loss provisions',
#    'rise',
#    'restructuring',
#    'Christian Sewing',
#    'loss',
#    'profit',
#    'profit',
#    'Group',
#    'credit losses',
#    'Provision',
#    'management expectations',
#    'costs',
#    'effects',
#    'loss',
#    'loans',
#    'basis points',
#    'guidance',
#    'revenues',
#    'revenues',
#    'profit',
#    'profit',
#    'revenues',
#    'Core Bank',
#    'costs',
#    'Noninterest expenses',
#    'Prime Finance expenses',
#    'Equities',
#    'items',
#    'equity',
#    'Revenue growth',
#    'items',
#    'progress',
#    'progress',
#    'exit',
#    'earnings momentum',
#    'return',
#    'revenues',
#    'Investment Bank',
#    'costs',
#    'targets',
#    'credit losses',
#    'partnership',
#    'agreement',
#    'Chief Executive Officer',
#    'environment',
#    'track',
#    'provision',
#    'growth',
#    'clients',
#    'conditions',
#    'capital position',
#    'resilience',
#    'Corporate Bank',
#    'Google Cloud',
#    'Integration',
#    'scope',
#    'transformation',
#    'investment',
#    'financing',
#    'target',
#    'entity merger',
#    'Private Bank',
#    'International Private Bank',
#    'Germany',
#    'Wealth Management and Private & Commercial Business International',
#    '2019',
#    '158 million euros',
#    '946 million euros',
#    '61 million euros',
#    '3.1 billion euros',
#    '761 million euros',
#    '753 million euros',
#    '489 million euros',
#    '6.3 billion euros',
#    '6.4 billion euros',
#    '6.3 billion euros',
#    '5.4 billion euros',
#    '4.8 billion euros',
#    '200 billion euro',
#    '761 million',
#    '3.1 billion',
#    '158 million',
#    '2',
#    '489 million',
#    '61 million',
#    '3.4',
#    '6.4 billion',
#    '8',
#    '6.3 billion',
#    '5.4 billion',
#    '2',
#    '52',
#    '753 million',
#    '46',
#    '1',
#    '6.3 billion',
#    '4.8 billion',
#    '6',
#    '200 billion',
#    '45',
#    '23',
#    '946 million',
#    '35',
#    '10',
#    '2019'],
#   'topics': ['/Finance']},
#  '4827979632869376': {'text': '<p>Moody&rsquo;s Investors Service today placed all Deutsche Bank&rsquo;s ratings on review for upgrade. A review for upgrade implies the possibility of a rating action within a shorter timeframe and is typically concluded within 30 to 90 days, according to the agency.</p>\n<p>Moody&rsquo;s states: &ldquo;the review for upgrade takes account of Deutsche Bank&rsquo;s swift and pronounced progress towards its objective of achieving a more balanced and sustainable business model&hellip;coupled with the bank&rsquo;s unchanged solid capital and liquidity buffers.&rdquo;</p>\n<p>James von Moltke, Chief Financial Officer, said: &ldquo;I am delighted and encouraged by this move from Moody&rsquo;s, which follows outlook upgrades from other rating agencies in recent months. We are steadily gaining recognition with these key stakeholders for the disciplined execution of our transformation strategy. Our priority now must be to maintain that discipline, and make further progress on our ratings.&rdquo;</p>\n<p><strong>Earnings strength and strong balance sheet management: key factors in self-financing Deutsche Bank&rsquo;s transformation</strong></p>\n<p>In respect of disciplined execution of transformation, Moody&rsquo;s noted: &ldquo;Since Deutsche Bank announced its strategic overhaul in summer 2019, it has provided for almost &euro;7 billion of restructuring and transformation charges and &euro;1.8 billion in loan loss provisions.&rdquo;</p>\n<p>For Moody&rsquo;s, Deutsche Bank&rsquo;s suc',
#   'timestamp': '2022-09-15 19:15:47.812419+00:00',
#   'sentiment': 'positive',
#   'entities': ['Deutsche Bank',
#    'upgrade',
#    "Moody's Investors Service",
#    'review',
#    'ratings',
#    'review',
#    'bank',
#    'agency',
#    'capital',
#    'success',
#    'James von Moltke',
#    'Credit quality',
#    'account',
#    'rating action',
#    'progress',
#    'liquidity',
#    'possibility',
#    'timeframe',
#    'buffers',
#    'business model',
#    'objective',
#    'overhaul',
#    'move',
#    'ratings',
#    'rating agencies',
#    'outlook upgrades',
#    'earnings strength',
#    'transformation',
#    'bank',
#    'factors',
#    'agency',
#    'sustainability',
#    'capital ratios',
#    'execution',
#    'balance sheet management',
#    'priority',
#    'stakeholders',
#    'transformation strategy',
#    'Earnings strength',
#    'upgrade',
#    'upgrade',
#    'agency',
#    'sustainability',
#    'transformation',
#    'transformation',
#    'recognition',
#    'financing transformation',
#    'bank',
#    'bank',
#    'discipline',
#    'respect',
#    'review',
#    'markets',
#    'progress',
#    'capital',
#    'ratings',
#    'Investment Bank',
#    'overhaul',
#    'self-finance',
#    'risk management',
#    'investment',
#    'revenues',
#    'execution',
#    'capital markets',
#    'earnings',
#    'Private Bank',
#    'Corporate Bank',
#    'revenues',
#    'revenues',
#    'risk exposures',
#    'exposures',
#    'liquidity',
#    'earnings momentum',
#    'controls',
#    'technology',
#    'rating agencies',
#    'momentum',
#    'market funding',
#    'impact',
#    'dependence',
#    'path',
#    'achievements',
#    'part',
#    'loan loss provisions',
#    'restructuring',
#    'charges',
#    'resources',
#    'exposure consumption',
#    'operating costs',
#    'Moody',
#    'ratings outlook',
#    'ability',
#    'market environment',
#    'risk appetite',
#    'backdrop',
#    'interest rate headwinds',
#    'focus industries',
#    'sectors',
#    'loan book',
#    'magnitude',
#    'ratings',
#    'sustainability leader',
#    'stakeholders',
#    'sustainability strategy',
#    'turnaround',
#    'turnaround',
#    'upgrade',
#    'agencies',
#    'rating agencies',
#    'review',
#    'peers',
#    'event',
#    'details',
#    'ratings prospects',
#    'ratings outlook',
#    'outlook',
#    'ratings outlook',
#    'move',
#    'move',
#    'overview',
#    'ambition',
#    'action',
#    'Fitch Ratings',
#    'agency',
#    'upgrade review',
#    'sustainability',
#    'execution',
#    'transformation',
#    'factors',
#    'factors',
#    'Sustainability Deep Dive',
#    'controls',
#    'sustainability leadership',
#    'pandemic',
#    'real estate',
#    'aviation',
#    'leisure',
#    'profitability',
#    'risk management infrastructure',
#    'technology platform',
#    'digitalisation',
#    'S&P',
#    'role',
#    '2019',
#    'November 2020',
#    '&euro;7 billion',
#    '&euro;1.8 billion',
#    '2020',
#    'three',
#    'three',
#    'two',
#    '30',
#    '1.8 billion',
#    'six',
#    'two',
#    '90',
#    '2019',
#    '7 billion',
#    'six'],
#   'topics': ['/Finance/Investing', '/Finance/Banking']},
#  '4830166937239552': {'text': '<p>&ldquo;One bank stood out for its comprehensive response to the coronavirus crisis when faced with a test of resilience and when standard business continuity plans no longer applied,&rdquo; said GlobalCapital Asia, naming Deutsche Bank the best bank in the region for handling the pandemic.</p>\n<p>The publication continued: &ldquo;For understanding the tone of market rapidity, offering innovative and much-needed solutions to its client base and for adjusting its focus in line with the changing conditions, Deutsche Bank deserves kudos for its COVID response.&rdquo;</p>\n<p>This is the second time the bank has been commended for rising to the challenge of COVID, having won&nbsp;<a href="https://www.db.com/news/detail/20200911-deutsche-bank-recognised-for-exceptional-client-service-and-innovative-risk-management-in-asia-including-crisis-response-of-the-year?language_id=1" title="AsiaRisk award &lsquo;Crisis Response of the Year&rsquo;">&lsquo;Crisis Response of the Year&rsquo;</a> from AsiaRisk in September.</p>\n<p>&ldquo;Winning another &ldquo;Best COVID Response&rdquo; award this year is testament to the resilience and agility of our people and platform, from front of house through to our back line. We are super proud of how well we&rsquo;ve held up and supported clients this year,&rdquo; said Michael Connolly, Deutsche Bank&rsquo;s Chief Operating Officer for the Corporate Bank and Investment Bank in APAC.</p>\n<p><strong>Award-winning adaptability and tailored transactions<',
#   'timestamp': '2022-09-15 19:18:13.474489+00:00',
#   'sentiment': 'positive',
#   'entities': ['Deutsche Bank',
#    'GlobalCapital Asia',
#    'bank',
#    'bank',
#    'response',
#    'resilience',
#    'region',
#    'coronavirus crisis',
#    'test',
#    'business continuity',
#    'bank',
#    'pandemic',
#    'publication',
#    'clients',
#    'solutions',
#    'Investment Bank',
#    'line',
#    'focus',
#    'payment',
#    'tone',
#    'conditions',
#    'market rapidity',
#    'client base',
#    'bank',
#    'shareholder',
#    'Trans Retail Indonesia',
#    'Michael Connolly',
#    'bank',
#    'response',
#    'app',
#    'award',
#    'Amit Khattar',
#    'bank',
#    'Investment Bank',
#    'bank',
#    'bond',
#    'client',
#    'client',
#    'clients',
#    'clients',
#    'clients',
#    'challenge',
#    'resilience',
#    'back line',
#    'bond',
#    'transactions',
#    'kudos',
#    'bank',
#    'another',
#    'house',
#    'agility',
#    'front',
#    'people',
#    'platform',
#    'transactions',
#    'capital markets',
#    'US',
#    'markets',
#    'high yield market',
#    'solutions',
#    'equipment',
#    'COVID',
#    'clients',
#    'bonds',
#    'Crisis Response of the Year',
#    'AsiaRisk',
#    'Best COVID Response',
#    'CB',
#    'Sriram Transport',
#    'roles',
#    'part',
#    'themes',
#    'publication',
#    'loans',
#    'dollar loan',
#    '3SBio',
#    'needs',
#    'hospitals',
#    'entity',
#    'capital injection',
#    'lock',
#    'most',
#    'adaptability',
#    'trades',
#    'client demand',
#    'increase',
#    'access',
#    'execution',
#    'shortage',
#    'funding',
#    'dollar liquidity support',
#    'liability management',
#    'roles',
#    'bond',
#    'bond',
#    'bonds',
#    'bond',
#    'ESG',
#    'Asia',
#    'India',
#    'China',
#    'result',
#    'loan deal categories',
#    'take-private',
#    'deal',
#    'APAC',
#    'wins',
#    'bank',
#    'APAC',
#    'spike',
#    'Best Loan',
#    'Best High Yield Syndicated Loan',
#    'Portugal',
#    'Portuguese',
#    'Autobahn',
#    'clients',
#    'clients',
#    'convertible bond',
#    'Best Leveraged/Acquisition Finance',
#    'teams',
#    'Best HY Corporate Bond',
#    'Best SSA Bond',
#    'landmark transactions',
#    'transactions',
#    'equity market',
#    'Hexaware Technologies',
#    'Baring Private Equity',
#    'Kaisa Group',
#    'Best of South Asia',
#    'Megatrend Deal of the Year',
#    'FinanceAsia Awards',
#    'role',
#    'region',
#    'challenges',
#    'shares',
#    'loan team',
#    'Republic of Indonesia',
#    'hit',
#    'solutions',
#    "Best Project Finance Deal' for Star Energy",
#    'Vedanta Resource',
#    '2020',
#    '500 million US dollars',
#    '740 million US dollar',
#    '600 million US dollars',
#    '4.3 billion US dollar',
#    '1.4 billion US dollar',
#    '790 million US dollar',
#    '600 million',
#    '4.3 billion',
#    'three',
#    '790 million',
#    'three',
#    '2020',
#    '300',
#    '740 million',
#    '500 million',
#    '3',
#    '1.4 billion',
#    'four'],
#   'topics': ['/Finance', '/Business & Industrial/Business Finance']},
#  '4847079553761280': {'text': '<div>\n<div><span> </span>\n<p>Coronavirus and its economic impact have put a renewed focus on corporate governance &ndash; the subject of the latest special report by Deutsche Bank&rsquo;s International Private Bank on Environmental, Social and Governance (ESG) themes.</p>\n<p>The report argues that:</p>\n<ul>\n<li><strong>Governance is a source of corporate resilience.</strong> During the pandemic, good governance has allowed firms not only to maintain basic functions, such as cash flow and fulfilling contractual obligations, but has also helped them to keep their workforce and customers safe.</li>\n<li><strong>The scope of governance will widen further in future.</strong> The socio-economic effects of this crisis, including the growing involvement of governments in many areas, will put new demands on corporate governance. Environmental aspects are also likely to stay prominent.</li>\n<li><strong>Future governance changes will require a sense of balance.</strong> In a constantly changing environment, new approaches will need to evolve to address a range of concerns in a financially sustainable way that balances the needs of individuals, governments, corporates and investors.</li>\n</ul>\n<p><a href="https://deutschewealth.com/en/our_perspective/esg-specials/g-in-esg.html" title="The &ldquo;G&rdquo; in ESG: Governance &ndash; a question of balance" target="_blank">The report</a> provides an overview of governance components and studies their impact on firms&rsquo; performance. It al',
#   'timestamp': '2022-09-15 19:20:03.794925+00:00',
#   'sentiment': 'positive',
#   'entities': ['report',
#    'Coronavirus',
#    'governance',
#    'Governance',
#    'impact',
#    'governance',
#    'subject',
#    'focus',
#    'firms',
#    'Deutsche Bank',
#    'International Private Bank on Environmental',
#    'governance',
#    'ESG',
#    'third',
#    'Social and Governance',
#    'themes',
#    'functions',
#    'governments',
#    'governance',
#    'governance changes',
#    'resilience',
#    'governance',
#    'effects',
#    'environment',
#    'demands',
#    'crisis',
#    'areas',
#    'cash flow',
#    'customers',
#    'obligations',
#    'scope',
#    'balance',
#    'approaches',
#    'workforce',
#    'aspects',
#    'firms',
#    'firms',
#    'impact',
#    'way',
#    'reports',
#    'performance',
#    'history',
#    'guest contribution',
#    'reports',
#    'involvement',
#    'governments',
#    'investing',
#    'components',
#    'social',
#    'series',
#    'E',
#    'sense',
#    'report',
#    'German',
#    'investors',
#    'governance components',
#    'needs',
#    'concerns',
#    'range',
#    'individuals',
#    'corporates',
#    'overview'],
#   'topics': ['/Finance', '/Business & Industrial']},
#  '4848319658459136': {'text': '<p>Deutsche Bank is offering Belgian customers a new green investment product that will enable them to make a concrete and visible impact on the environment. Part of the profits from the sale of the product &ndash; called &ldquo;Deutsche Bank AG Green Note Fund Opportunity (90) 2031&rdquo;* &ndash; will be donated to Farming for Climate, a non-profit organisation whose mission is to accompany and financially support Belgian farmers in their transition towards more sustainable agricultural practices.</p>\n<p>The green investment product, available to retail customers from December 7, is based on the assets out of the externally validated Deutsche Bank green asset pool. Part of the bank&rsquo;s profits from the product&nbsp;&ndash; 25 percent of the distribution margin&nbsp;&ndash; will be paid to Farming for Climate.</p>\n<blockquote class="quote-box">Over the next five years, local farmers will benefit from Farming for Climate\'s guidance and support in their transition to more sustainable agriculture. The greater the amount invested, the greater the support given to Farming for Climate.</blockquote>\n<p>In order to make our investors&rsquo; impact concrete and visible, Deutsche Bank, in collaboration with Farming for Climate, will regularly update investors on the progress made by those local farmers benefiting from the program&rsquo;s support. Through the Belgium branch network, Deutsche Bank will arrange client events to give our customers the chance to meet these farmers in ',
#   'timestamp': '2022-09-15 19:18:28.578414+00:00',
#   'sentiment': 'positive',
#   'entities': ['Deutsche Bank',
#    'product',
#    'customers',
#    'Part',
#    'farmers',
#    'Farming for Climate',
#    'farmers',
#    'investment product',
#    'concrete',
#    'environment',
#    'Farming for Climate',
#    'impact',
#    'CCO',
#    'Belgian',
#    'transition',
#    'collaboration',
#    'farmers',
#    'Olivier Delfosse',
#    'mission',
#    'practices',
#    'profits',
#    'organisation',
#    'sale',
#    'bank',
#    'investment product',
# ...
#   'timestamp': '2022-09-15 19:14:17.621364+00:00',
#   'sentiment': 'positive',
#   'entities': ['consumers',
#    'environment',
#    'revolution',
#    'brands',
#    'beliefs',
#    'shopping habits',
#    'generation',
#    'values',
#    'terms',
#    'image building',
#    'report',
#    'ESG',
#    'Luxury goods companies'],
#   'topics': ['/People & Society/Social Issues & Advocacy/Green Living & Environmental Issues']},
#  '6325007395323904': {'text': "<p>Ladies and gentlemen,</p>\n<p>I am aware that you all have several hours of interesting presentations and discussions behind you. I have been told how intense the debates have been. That's why I'm particularly sorry that I couldn't be here from the beginning.</p>\n<p>And I am all the more grateful to Mathias D&ouml;pfner that I can now open the evening's session. I would like to be very frank here about what I see as the issues at stake in the Bundestag election. There&rsquo;s been a lot of talk about this being a key election. I would see that as an understatement.</p>\n<p>It is not just that there is a lot at stake. No, it's crunch time, so to speak. We are on the cusp of a decade in which, as in the 1920s, crucial decisions will be made. The only difference is that this time, the course that we set can lead to very good results.</p>\n<p>The importance of this election became clear to me last week in London. For the first time since the outbreak of the Covid pandemic, we had gathered our largest institutional clients, people who collectively manage more than 30 trillion euros in assets. The interest that investors showed in the German election and how much they knew about it surprised me.</p>\n<p>It made me realise: the world is watching us right now, and it's not just investors who want to know what will become of this boy wonder in Europe, which has performed so formidably in the past decade.</p>\n<p>If, on the other hand, we look at how this election is discussed in German",
#   'timestamp': '2022-09-15 19:14:03.778549+00:00',
#   'sentiment': 'negative',
#   'entities': ['economy',
#    'election',
#    'Europe',
#    'world',
#    'investors',
#    'course',
#    'interest',
#    'cusp',
#    'people',
#    'investors',
#    'hand',
#    'Ladies',
#    'gentlemen',
#    'man',
#    'session',
#    'attitude',
#    'time',
#    'debates',
#    'election',
#    'election',
#    'election',
#    'decisions',
#    'lot',
#    'assets',
#    'difference',
#    'wealth',
#    'presentations',
#    'beginning',
#    'stake',
#    'stake',
#    'discussions',
#    'issues',
#    'understatement',
#    'results',
#    'importance',
#    'pandemic',
#    'clients',
#    'outbreak',
#    'boy wonder',
#    'conditions',
#    'Agenda',
#    'lot',
#    'companies',
#    'euro',
#    'all',
#    'Covid',
#    'account surplus',
#    'environment',
#    'digitalisation',
#    'election',
#    'Mathias Döpfner',
#    'Bundestag',
#    'London',
#    'countries',
#    'economy',
#    'vision',
#    'euro',
#    'euro',
#    'engine',
#    'talk',
#    'answer',
#    'rules',
#    'state',
#    'German',
#    'return',
#    'everything',
#    'money',
#    'technology',
#    'picture',
#    'investments',
#    'investments',
#    'investment',
#    'antitrust law',
#    'capital market',
#    'planet',
#    'Some',
#    'investments',
#    'country',
#    'country',
#    'investment',
#    'problem',
#    'return',
#    'candidates',
#    'weaknesses',
#    'poll numbers',
#    'defense',
#    'redistribution',
#    'attack',
#    'situation',
#    'neighbours',
#    'chill',
#    'world',
#    'covid crisis',
#    'anywhere',
#    'action',
#    'doomsayer',
#    'finances',
#    'strategy',
#    'capital market',
#    'market economy',
#    'billions',
#    'way',
#    'gifts',
#    'economy',
#    'state capital',
#    'Economist',
#    'assets',
#    'assets',
#    'everything',
#    'boom',
#    'boom',
#    'boom',
#    'estimates',
#    'words',
#    'world market leader',
#    'money',
#    'covid',
#    'hand',
#    'Agenda 2010',
#    'wage restraint',
#    'end',
#    'consequences',
#    'assets',
#    'capital market',
#    'sustainability',
#    'shortage',
#    'market',
#    'problems',
#    'returns',
#    'opportunity',
#    'restrictions',
#    'opportunity',
#    'course',
#    'beginning',
#    'fact',
#    'reforms',
#    'export surpluses',
#    'president',
#    'shows',
#    'window',
#    'world',
#    'world',
#    'world',
#    'combination',
#    'class',
#    'touch',
#    'headline',
#    'countries',
#    'words',
#    'interest rates',
#    'investment requirement',
#    'strengths',
#    'digitalisation',
#    'one',
#    'problem',
#    'Germans',
#    'bureaucracy',
#    'potential',
#    'one',
#    'reform programme',
#    'cornerstones',
#    'dimensions',
#    'home',
#    'table',
#    'investment gap',
#    'upheaval',
#    'decisions',
#    'whole',
#    'trade',
#    'export nation',
#    'exchange rate stability',
#    'pandemic',
#    'frictions',
#    'phenomenon',
#    'supply chains',
#    'glocalisation',
#    'withdrawal',
#    'competition',
#    'competition',
#    'billions',
#    'consequences',
#    'strategy',
#    'area',
#    'investment location',
#    'legislation',
#    'taxes',
#    'individuals',
#    'transformation',
#    'capital markets union',
#    'poverty',
#    'elderly',
#    'prices',
#    'pensions',
#    'democracy',
#    'backbone',
#    'society',
#    'danger',
#    'thesis',
#    'process',
#    'Climate protection',
#    'capital goods manufacturers',
#    'majority decisions',
#    'rest',
#    'rule',
#    'all',
#    'treasure trove',
#    'United States',
#    'governance',
#    'leadership role',
#    'unanimity requirement',
#    'policy',
#    'answers',
#    'leadership role',
#    'strengths',
#    'culture',
#    'knowledge',
#    'approach',
#    'world',
#    'everyone',
#    'framework',
#    'idea',
#    'China',
#    'country',
#    'country',
#    'country',
#    'champions',
#    'phrase',
#    'world stage',
#    'entity',
#    'negotiating power',
#    'questions',
#    'values',
#    'languages',
#    'company',
#    'change',
#    'Many',
#    'Green Deal',
#    'plan',
#    'point',
#    'Some',
#    'measures',
#    'Democratic',
#    'Afghanistan',
#    'something',
#    'area',
#    'culture',
#    'bank',
#    'attitude',
#    'bank',
#    'scale',
#    'scale',
#    'measures',
#    'politics',
#    'Herbert Diess',
#    'museum',
#    'government',
#    'earth',
#    'both',
#    'ambition',
#    'responsibility',
#    'employees',
#    'conviction',
#    'work',
#    'lives',
#    'signal',
#    'mind',
#    'election campaign',
#    'fingers',
#    'heart',
#    'EU',
#    'mentality',
#    'Brussels',
#    'export boom',
#    'government',
#    'investment',
#    'companies',
#    'technology',
#    'change',
#    'opportunities',
#    'sustainability',
#    'construction',
#    'change',
#    'technology',
#    'goal',
#    'motto',
#    'Everyone',
#    'example',
#    'mobility solutions',
#    'show',
#    'solutions',
#    'sustainability knowledge',
#    'entrepreneurship',
#    'battery factory',
#    'entrepreneurship',
#    'way',
#    'bureaucracy',
#    'kind',
#    'government intervention',
#    'trains',
#    'cars',
#    'aircraft',
#    'permits',
#    'costs',
#    'authorities',
#    'structures',
#    'effort',
#    'state budget',
#    'part',
#    'proposals',
#    'regard',
#    'Fourth',
#    'capabilities',
#    'engineering expertise',
#    'John F. Kennedy',
#    'example',
#    'digital',
#    'VW',
#    'IAA',
#    'Brandenburg',
#    'Tesla',
#    'BDI',
#    'June 5, 1999',
#    '2010',
#    '1975',
#    '2020',
#    '2050',
#    '2010',
#    '30 trillion euros',
#    '1.9 trillion euros',
#    '50 billion euros',
#    '2.0',
#    '2010',
#    'three',
#    '20',
#    '50 billion',
#    '1999',
#    'one',
#    'three',
#    '30 trillion',
#    '5',
#    '2020',
#    'one',
#    '1920',
#    '1975',
#    '2030',
#    '2050',
#    'five',
#    'two',
#    'two',
#    '26',
#    '2010',
#    'ten',
#    'one',
#    '1.9 trillion',
#    'two',
#    'three'],
#   'topics': ['/Business & Industrial', '/News/Business News']},
#  '6326237970563072': {'text': '<p>Deutsche Bank (XETRA: DBKGn.DB / NYSE: DB) has become the first bank to join the&nbsp;<a href="https://www.oceanriskalliance.org/" target="_blank" title="Ocean Risk and Resilience Action Alliance (ORRAA)">Ocean Risk and Resilience Action Alliance (ORRAA)</a> as a full member, creating a partnership dedicated to bringing financial expertise and innovation to protect the ocean and the communities that depend on it.</p>\n<p>The International Private Bank (IPB) of Germany&rsquo;s largest bank will partner with ORRAA to encourage global action and private finance to invest in marine and coastal natural capital, to promote a sustainable blue economy and to build resilience in the regions most vulnerable to ocean-related risks, including sea-level rise and extreme weather events.</p>\n<p>Launched at the United Nations&rsquo; Secretary General&rsquo;s Climate Action Summit in 2019, ORRAA is a multi-sector collaboration between governments, financial institutions, insurance companies, environmental organisations and other stakeholders that aims to drive US$500 million of investment into coastal and marine ecosystems by 2030.</p>\n<p>The partnership will offer new areas of engagement and impact to the bank&rsquo;s clients, starting initially with ocean resilience research developed in close collaboration with ORRAA. Deutsche Bank International Private Bank has a long track record of offering environmental, social and governance (ESG) themed investments, integrating sustainability into',
#   'timestamp': '2022-09-15 19:15:50.792388+00:00',
#   'sentiment': 'positive',
#   'entities': ['ORRAA',
#    'Deutsche Bank',
#    'Claudio de Sanctis',
#    'ocean',
#    'communities',
#    'bank',
#    'partnership',
#    'innovation',
#    'member',
#    'expertise',
#    'bank',
#    'Deutsche Bank International Private Bank',
#    'Ocean Risk',
#    'DB',
#    'DBKGn.DB',
#    'NYSE',
#    'Resilience Action Alliance',
#    'XETRA',
#    'carbon sink',
#    'finance',
#    'action',
#    'International Private Bank',
#    'resilience',
#    'ORRAA',
#    'event',
#    'Banks',
#    'Germany',
#    'partnership',
#    'ecosystems',
#    'risks',
#    'investment',
#    'ecosystems',
#    'bank',
#    'ESG',
#    'events',
#    'governments',
#    'ocean',
#    'ocean',
#    'sustainability',
#    'economy',
#    'regions',
#    'weather',
#    'capital',
#    'sustainability',
#    'Secretary General',
#    'stakeholders',
#    'institutions',
#    'organisations',
#    'insurance companies',
#    'ocean',
#    'senior managers',
#    'clients',
#    'clients',
#    'bank',
#    'clients',
#    'change',
#    'climate risks',
#    'investments',
#    'milestone',
#    'impact',
#    'ecosystem',
#    'partnership',
#    'part',
#    'force',
#    'impact',
#    'world',
#    'ocean resilience research',
#    'engagement',
#    'collaboration',
#    'governance',
#    'risk research',
#    'areas',
#    'client engagement',
#    'CEO',
#    'society',
#    'heart',
#    'everything',
#    'childhood',
#    'much',
#    'environment',
#    'damage',
#    'United Nations',
#    'biodiversity',
#    'track record',
#    'investment processes',
#    'sea-level rise',
#    'climate',
#    'change',
#    'ocean change',
#    'potential',
#    'thought leadership',
#    'planet',
#    'mangroves',
#    'coral reefs',
#    'ways',
#    'Climate Action Summit',
#    'impacts',
#    'host',
#    'world',
#    'communities',
#    'assets',
#    'pace',
#    'sustainability strategy',
#    'resilience',
#    'Sustainability Deep Dive',
#    'Karen Sack',
#    'site',
#    'climate change',
#    'performance management',
#    'climate risk management',
#    'diversity',
#    'EMEA',
#    'business heads',
#    'bank experts',
#    'information',
#    'information',
#    'Email',
#    'Email',
#    'details',
#    'oceans',
#    'sessions',
#    'topics',
#    'Chief Executive Officer',
#    'presentations',
#    'taxonomy',
#    'inclusion',
#    'Media Relations',
#    'role',
#    "United Nations' Sustainable Development Goals",
#    'ecosystems',
#    'investment',
#    'areas',
#    'benefits',
#    'millions',
#    'people',
#    'value',
#    'understanding',
#    'finance sector',
#    'ambition',
#    'Christian Sewing',
#    'Adrian Cox',
#    'Eva Mairinger',
#    'lack',
#    'innovation',
#    'way',
#    'Earth',
#    '+44 20 7541 7775',
#    '+41 44 224 5951',
#    '2019',
#    '2030',
#    'Thursday, May 20',
#    'US$500 million',
#    '224',
#    '+44',
#    '20',
#    '7541',
#    '500 million',
#    '7775',
#    '44',
#    '2019',
#    '20',
#    '5951',
#    '2030',
#    '+41',
#    'three'],
#   'topics': ['/Business & Industrial/Business Finance', '/Finance']},
#  '6331173022203904': {'text': '<p><strong>Why are we holding our own sustainability event?</strong><br />We&rsquo;re aiming to provide a transparent, focused report on all the bank&rsquo;s achievements over the past months and years. But what&rsquo;s even more important: we aim to show where Deutsche Bank is heading on the sustainability front &ndash; and why that will be important for our clients, our staff, our shareholders, non-governmental organisations and society at large.</p>\n<p><strong>Who can participate?</strong><br />You can &ndash; if you are interested in environmental, social and governance (ESG) topics and would like to know why a bank like ours can play a key role in transforming the economy and society into sustainably operating entities.</p>\n<p><strong><a href="https://dbevents.cventevents.com/eXEoKG?rt=xHp86IMYikyNp718ry1Wcw&amp;RefId=Client" target="_blank" title="Sustainability Deep Dive 2021 &ndash; Registration (opens new window)"><img src="/files/images/2021/05-may/sustainability-deep-dive-may-20.jpg?language_id=3" alt="Sustainability Deep Dive" width="400" height="224" class="float-right" /></a>How can I register?</strong><br />Click&nbsp;<a href="https://dbevents.cventevents.com/event/9318cb9c-b63a-40a3-8bd9-82ffd2e85b8f/websitePage:1e010f51-be65-4979-8487-0f2d09e37589?RefId=Client&amp;rt=xHp86IMYikyNp718ry1Wcw" target="_blank" title="Access our virtual Sustainability Deep Dive">here</a> and enter your details. You may also register while the event is already in progress.</p>\n<p>',
#   'timestamp': '2022-09-15 19:15:58.035064+00:00',
#   'sentiment': 'positive',
#   'entities': ['sustainability event',
#    'clients',
#    'bank',
#    'clients',
#    'achievements',
#    'sustainability front',
#    'staff',
#    'shareholders',
#    'report',
#    'Deutsche Bank',
#    'SDD',
#    'bank',
#    'sustainability strategy',
#    'Americas Christiana Riley',
#    'bank',
#    'speakers',
#    'event',
#    'agenda',
#    'Corporate Bank',
#    'society',
#    'society',
#    'topics',
#    'event',
#    'Corporate Bank',
#    'organisations',
#    'economy',
#    'governance',
#    'entities',
#    'details',
#    'Management Board member',
#    'reporting',
#    'strategy',
#    'heads',
#    'International Private Bank',
#    'risk management',
#    'topic',
#    'CEO',
#    'businesses',
#    'event',
#    'event',
#    'Viktoriya Brand',
#    'transformation',
#    'transition',
#    'Investment Bank',
#    'ways',
#    'finance',
#    'course',
#    'progress',
#    'presentations',
#    'business model',
#    'addition',
#    'plans',
#    'ambitions',
#    'regard',
#    'diversity',
#    'inclusion',
#    'operations',
#    'CFO',
#    'data',
#    'ESG',
#    'Gerald Podobnik',
#    'event',
#    'event',
#    'role',
#    'implementation',
#    'questions',
#    'chat function',
#    'start',
#    'Global Head of Human Resources Michael Ilgner',
#    'recording',
#    'presentations',
#    'Germany',
#    'Claudio de Sanctis',
#    'Lars Stoy',
#    'Stefan Hoops',
#    'Claire Coustar',
#    'Christian Sewing',
#    'Mark Fedorcik',
#    'speakers',
#    'Video recordings',
#    'English',
#    'German',
#    'bank',
#    'event',
#    'agenda items',
#    'presentations',
#    'sustainability strategy',
#    'areas',
#    'sustainability activities',
#    'forces',
#    'initiators',
#    'course',
#    'Group Enterprise Risk Management',
#    'Head of Group Sustainability',
#    'CRO',
#    'Chris Jaques',
#    'Jörg Eigendorf',
#    'Monday, May 24',
#    '24'],
#   'topics': ['/Finance/Banking']}}

# %%
import requests
backend_api='https://gee16-22-team12.ew.r.appspot.com/api/text'
news_json = requests.get(backend_api).json()

# %%
for key, value in news_json.items():
    print(value['topics'])
# Out:
# ['/People & Society']
# ['/Finance', '/Business & Industrial']
# ['/Finance/Banking']
# ['/Finance/Banking']
# ['/Finance']
# ['/Finance', '/Business & Industrial']
# ['/Business & Industrial']
# ['/Finance/Banking']
# ['/Finance']
# ['/Finance/Investing', '/Finance/Banking']
# ['/Finance', '/Business & Industrial/Business Finance']
# ['/Finance', '/Business & Industrial']
# ['/Business & Industrial/Business Finance']
# ['/Finance/Investing']
# ['/Business & Industrial/Business Services/E-Commerce Services', '/Computers & Electronics/Enterprise Technology']
# ['/Finance/Banking']
# ['/Business & Industrial/Business Finance', '/Finance']
# ['/Business & Industrial']
# ['/News/Business News', '/Business & Industrial/Business Finance', '/Finance']
# ['/Finance/Accounting & Auditing', '/Business & Industrial']
# ['/Sensitive Subjects', '/People & Society/Social Issues & Advocacy']
# ['/Business & Industrial']
# ['/Finance', '/Business & Industrial']
# ['/Finance', '/Business & Industrial/Business Finance']
# ['/Law & Government/Government', '/People & Society/Social Issues & Advocacy', '/Health/Health Conditions/AIDS & HIV', '/Health/Reproductive Health']
# ['/Finance/Banking']
# []
# ['/Finance/Investing']
# ['/People & Society/Social Issues & Advocacy/Green Living & Environmental Issues']
# ['/People & Society', '/Business & Industrial/Business Finance']
# ['/Finance/Banking', '/Business & Industrial']
# ['/Business & Industrial']
# ['/Finance/Banking']
# ['/Finance', '/Business & Industrial/Business Finance']
# ['/Business & Industrial/Business Services']
# ['/Business & Industrial', '/Finance']
# ['/Business & Industrial', '/Finance/Banking', '/Finance/Investing']
# ['/Finance']
# ['/Finance/Banking', '/Finance/Investing']
# ['/Business & Industrial', '/People & Society/Social Issues & Advocacy']
# ['/Business & Industrial/Business Finance/Venture Capital']
# ['/People & Society/Social Issues & Advocacy/Green Living & Environmental Issues']
# ['/Business & Industrial']
# ['/People & Society/Social Issues & Advocacy/Charity & Philanthropy']
# ['/Finance/Banking', '/Business & Industrial']
# ['/Finance/Banking']
# ['/People & Society/Social Issues & Advocacy/Charity & Philanthropy']
# ['/Finance', '/Business & Industrial']
# ['/Business & Industrial']
# ['/Finance', '/Business & Industrial/Business Finance']
# ['/Business & Industrial', '/Law & Government/Government']
# ['/Finance/Banking', '/Business & Industrial/Business Finance', '/Business & Industrial/Energy & Utilities']
# ['/Business & Industrial']
# ['/Finance/Banking', '/Finance/Credit & Lending']
# ['/Sensitive Subjects']
# ['/People & Society/Religion & Belief']
# ['/Finance/Banking']
# ['/Finance/Banking', '/Business & Industrial']
# ['/Business & Industrial/Business Finance', '/Finance/Banking']
# ['/Finance']
# []
# ['/Finance/Banking']
# ['/Finance/Banking']
# ['/Business & Industrial/Business Finance/Venture Capital', '/News/Business News']
# ['/Business & Industrial', '/Computers & Electronics/Enterprise Technology']
# ['/Business & Industrial']
# ['/Sensitive Subjects']
# ['/Finance', '/Business & Industrial/Business Finance']
# ['/Finance/Banking', '/Business & Industrial']
# ['/Finance', '/Business & Industrial']
# ['/People & Society/Social Issues & Advocacy']
# ['/Finance/Banking']
# ['/Finance/Investing']
# ['/Business & Industrial/Business Finance', '/Finance/Banking']
# ['/Business & Industrial']
# ['/Finance/Banking', '/Business & Industrial/Business Finance']
# ['/News/Business News', '/Business & Industrial/Business Finance/Venture Capital']
# ['/Finance/Investing']
# ['/Business & Industrial/Business Finance']
# ['/Finance/Banking', '/Business & Industrial/Business Finance']
# ['/Finance/Investing', '/Business & Industrial']
# ['/Finance/Banking']
# ['/Finance/Investing']
# ['/Finance/Investing', '/Business & Industrial']
# ['/Finance']
# ['/Finance/Investing']
# ['/Business & Industrial/Business Finance']
# ['/Finance']
# ['/Law & Government/Government', '/News']
# ['/Finance/Banking', '/Finance/Investing']
# ['/Business & Industrial/Business Finance', '/Finance/Banking']
# ['/Finance/Banking']
# ['/Finance']
# ['/Finance/Banking', '/Finance/Credit & Lending']
# ['/Arts & Entertainment/Movies']
# ['/Reference/Libraries & Museums', '/Travel/Tourist Destinations']
# ['/Finance/Banking']
# ['/Finance/Banking', '/Business & Industrial']
# ['/Finance/Banking']
# ['/Business & Industrial', '/Autos & Vehicles']
# ['/Finance']
# ['/Business & Industrial/Business Finance', '/Finance/Banking']
# ['/Computers & Electronics/Consumer Electronics', '/Internet & Telecom/Mobile & Wireless/Mobile Phones', '/Internet & Telecom/Service Providers']
# ['/Arts & Entertainment']
# ['/Finance/Accounting & Auditing', '/Business & Industrial']
# ['/Finance', '/Business & Industrial']
# ['/Health/Health Conditions', '/People & Society']
# ['/Business & Industrial']
# ['/Business & Industrial', '/Finance/Investing']
# ['/Business & Industrial', '/Finance', '/News/Business News']
# ['/Business & Industrial/Energy & Utilities/Electricity']
# ['/Finance']
# ['/Business & Industrial/Business Services/E-Commerce Services', '/Computers & Electronics/Enterprise Technology', '/Finance']
# ['/Business & Industrial/Energy & Utilities/Renewable & Alternative Energy']
# ['/Finance/Banking', '/Business & Industrial/Business Finance']
# ['/Business & Industrial/Business Finance', '/Business & Industrial/Energy & Utilities']
# ['/Finance', '/Business & Industrial']
# ['/Business & Industrial/Agriculture & Forestry/Forestry']
# ['/News']
# ['/Finance/Investing']
# ['/People & Society/Social Issues & Advocacy/Green Living & Environmental Issues', '/Science/Earth Sciences/Atmospheric Science', '/Science/Ecology & Environment/Climate Change & Global Warming', '/Business & Industrial/Energy & Utilities/Renewable & Alternative Energy']
# ['/News/Politics', '/Law & Government/Government']
# ['/Finance/Banking', '/Finance/Investing']
# ['/People & Society/Social Issues & Advocacy/Charity & Philanthropy']
# ['/Finance', '/Business & Industrial']
# ['/Finance']
# ['/Finance/Banking']
# ['/Finance/Banking']
# ['/Finance/Banking']
# ['/People & Society', '/Law & Government/Government']
# ['/Finance', '/Business & Industrial/Business Finance']
# ['/Business & Industrial']
# ['/Business & Industrial', '/Finance']
# ['/Business & Industrial/Business Finance', '/Finance/Banking']
# []
# ['/Health/Mental Health']
# ['/Business & Industrial', '/Finance']
# ['/Finance/Banking']
# ['/Business & Industrial', '/Finance']
# ['/News']
# ['/Business & Industrial', '/Finance']
# ['/Finance']
# ['/Business & Industrial/Business Finance', '/Finance/Banking']
# ['/People & Society/Social Issues & Advocacy', '/Finance']
# ['/Law & Government']
# ['/Business & Industrial', '/Computers & Electronics/Enterprise Technology']
# ['/Business & Industrial']
# ['/People & Society/Social Issues & Advocacy']
# ['/Business & Industrial/Business Finance']
# ['/Jobs & Education/Education/Colleges & Universities']
# ['/Business & Industrial', '/People & Society/Social Issues & Advocacy']
# ['/Finance/Banking']
# ['/Finance']
# ['/Finance']
# ['/Business & Industrial/Business Finance', '/Finance/Banking']
# ['/Finance']
# ['/Business & Industrial', '/Finance']
# ['/Finance']
# ['/Finance']
# ['/Business & Industrial/Energy & Utilities']
# ['/People & Society']
# ['/Business & Industrial/Energy & Utilities']
# ['/Business & Industrial/Business Finance']
# ['/News/Business News', '/Business & Industrial']
# ['/Business & Industrial']
# ['/People & Society/Social Issues & Advocacy']
# ['/Finance/Banking']
# ['/Law & Government/Government']
# ['/Finance/Banking', '/Finance/Credit & Lending']
# ['/Finance/Banking']
# ['/Finance/Banking']
# ['/Finance/Investing']
# ['/Finance/Banking']
# ['/Business & Industrial/Business Services']
# ['/Business & Industrial', '/Finance/Banking']
# ['/People & Society/Social Issues & Advocacy/Green Living & Environmental Issues', '/Science/Ecology & Environment/Climate Change & Global Warming', '/Science/Earth Sciences/Atmospheric Science']
# ['/Finance', '/Business & Industrial']
# ['/Finance/Investing']
# ['/Business & Industrial/Business Finance', '/Finance']
# []
# ['/Finance/Banking']
# ['/Finance/Banking']
# ['/Business & Industrial', '/Finance']
# ['/Finance/Investing', '/Business & Industrial']
# ['/Finance', '/Business & Industrial']
# ['/Finance', '/Business & Industrial/Business Finance']
# ['/Finance', '/Business & Industrial']
# ['/Finance']
# ['/Business & Industrial', '/Finance']
# ['/News/Politics', '/Law & Government/Government']
# ['/Business & Industrial/Business Services/E-Commerce Services', '/Computers & Electronics/Enterprise Technology', '/Finance']
# ['/Business & Industrial/Business Finance', '/Finance']
# ['/People & Society/Social Issues & Advocacy']
# ['/Finance/Investing/Currencies & Foreign Exchange']
# ['/People & Society/Social Issues & Advocacy']
# ['/Finance/Banking']
# ['/Finance/Banking']
# ['/Finance/Banking', '/Finance/Investing']
# ['/Finance']
# ['/Business & Industrial']
# ['/Finance']
# ['/Finance']
# ['/Finance/Banking']
# ['/Business & Industrial/Business Finance', '/Finance/Credit & Lending']
# ['/Business & Industrial']
# ['/Business & Industrial']
# ['/Business & Industrial/Business Finance', '/News/Business News']
# ['/Finance/Investing']
# ['/Finance', '/Business & Industrial']
# ['/Finance/Banking']
# ['/Finance/Banking']
# []
# ['/Business & Industrial', '/Law & Government/Public Safety']
# ['/Business & Industrial/Business Finance', '/Finance']
# ['/Business & Industrial/Energy & Utilities']
# ['/Business & Industrial']
# ['/Finance/Banking', '/Business & Industrial']
# ['/Finance', '/Business & Industrial/Business Finance']
# ['/Finance/Banking']
# ['/Business & Industrial/Business Finance', '/Finance/Banking']
# ['/Finance/Banking']
# ['/Reference/Libraries & Museums', '/Travel/Tourist Destinations']
# ['/Finance/Grants, Scholarships & Financial Aid', '/Sports']
# ['/Finance', '/Business & Industrial/Business Finance']
# ['/Finance/Investing']
# ['/News/Business News', '/Business & Industrial', '/Finance']
# ['/Finance', '/Business & Industrial/Business Finance']
# ['/Business & Industrial/Business Finance', '/Finance']
# ['/Business & Industrial', '/Finance']
# ['/Business & Industrial', '/Finance']
# ['/Finance/Banking']
# ['/Finance/Banking', '/Business & Industrial']
# []
# ['/Autos & Vehicles', '/Business & Industrial', '/Finance/Credit & Lending']
# []
# ['/Finance/Banking', '/Business & Industrial']
# ['/Business & Industrial/Business Finance', '/Finance/Banking']
# ['/Business & Industrial']
# ['/Finance/Banking']
# []
# ['/Business & Industrial', '/People & Society', '/News']
# ['/People & Society/Social Issues & Advocacy']
# ['/Finance/Investing']
# ['/Business & Industrial']
# ['/Finance/Banking']
# ['/Business & Industrial/Business Finance', '/Finance/Banking']
# ['/Finance']
# ['/Arts & Entertainment', '/News']
# ['/Finance/Banking']
# ['/Finance/Banking']
# ['/Business & Industrial/Business Services']
# ['/Business & Industrial/Business Finance', '/Finance/Banking']
# ['/Business & Industrial']
# ['/Business & Industrial/Energy & Utilities']
# ['/Hobbies & Leisure', '/Pets & Animals/Wildlife', '/Science/Earth Sciences']
# ['/Finance']
# ['/Law & Government/Government', '/News', '/Business & Industrial']
# ['/Business & Industrial/Business Finance', '/Finance']
# ['/Finance/Credit & Lending']
# ['/Business & Industrial/Business Finance', '/Finance/Banking']
# ['/Business & Industrial', '/People & Society/Social Issues & Advocacy']
# ['/Finance/Banking']
# ['/Health']
# ['/Finance', '/Business & Industrial']
# ['/Finance']
# ['/Finance/Banking']
# ['/Business & Industrial']
# ['/Business & Industrial/Business Finance', '/Finance']
# ['/Business & Industrial', '/News/Business News']
# ['/Business & Industrial', '/Computers & Electronics/Enterprise Technology']
# ['/Finance/Banking']
# ['/Business & Industrial', '/Finance/Banking', '/News/Business News']
# ['/Finance/Banking']
# ['/News/Business News', '/Business & Industrial', '/Finance']
# ['/Finance', '/Business & Industrial/Business Finance']
# ['/People & Society/Social Issues & Advocacy/Charity & Philanthropy']
# ['/Finance/Banking']
# []
# ['/Finance', '/Business & Industrial']
# ['/Business & Industrial', '/News/Business News', '/Finance/Investing']
# ['/Finance/Banking']
# ['/Finance']
# ['/Finance/Banking', '/Business & Industrial/Business Finance']
# ['/People & Society/Social Issues & Advocacy/Charity & Philanthropy']
# ['/Business & Industrial', '/Finance']
# ['/Law & Government/Government', '/News/Business News']
# ['/Finance/Banking']
# ['/Business & Industrial']
# ['/Finance/Banking', '/Business & Industrial']
# ['/Finance', '/Business & Industrial']
# ['/People & Society/Social Issues & Advocacy/Charity & Philanthropy', '/Business & Industrial']
# ['/People & Society/Social Issues & Advocacy', '/Law & Government']
# ['/Business & Industrial/Business Finance', '/Finance/Banking']
# ['/Finance/Banking']
# ['/Finance/Banking']
# []
# ['/Business & Industrial/Business Finance', '/Finance/Banking']
# ['/Finance/Investing']
# ['/People & Society/Social Issues & Advocacy']
# []
# ['/Finance/Banking']
# ['/Finance']
# ['/Business & Industrial', '/Finance']
# ['/Business & Industrial', '/News']
# ['/Finance/Banking', '/Business & Industrial/Business Services/E-Commerce Services', '/Computers & Electronics/Enterprise Technology']
# ['/Business & Industrial/Business Operations']
# ['/Travel/Air Travel', '/Finance/Credit & Lending']
# ['/Finance/Banking']
# ['/Finance/Banking']
# ['/Business & Industrial/Energy & Utilities/Oil & Gas']
# ['/Finance']
# []
# ['/Finance/Banking', '/Business & Industrial']
# ['/Finance/Banking', '/Business & Industrial/Business Finance']
# ['/Business & Industrial', '/News/Business News']
# ['/Finance']
# ['/People & Society']
# ['/Business & Industrial/Business Finance', '/Law & Government']
# ['/Finance/Accounting & Auditing']
# ['/Finance', '/Business & Industrial/Business Finance']
# ['/Finance/Banking', '/Business & Industrial/Business Finance']
# ['/Finance/Investing/Currencies & Foreign Exchange', '/Business & Industrial']
# ['/Business & Industrial', '/Computers & Electronics/Enterprise Technology']
# ['/Finance/Banking']
# []
# ['/Jobs & Education/Education']
# ['/Business & Industrial', '/Finance']
# ['/Finance/Investing', '/Business & Industrial']
# ['/Finance', '/Business & Industrial/Business Finance']
# ['/Business & Industrial/Business Finance', '/Finance']
# ['/Finance', '/Business & Industrial']
# ['/Finance/Investing', '/Business & Industrial']
# ['/News/Business News', '/Business & Industrial', '/People & Society/Social Sciences/Economics']
# ['/Health', '/People & Society']
# ['/People & Society/Social Issues & Advocacy/Green Living & Environmental Issues', '/Science/Ecology & Environment/Climate Change & Global Warming']
# ['/Travel/Tourist Destinations', '/Arts & Entertainment/Visual Art & Design']
# ['/Finance', '/Business & Industrial']
# ['/Finance/Investing']
# ['/Arts & Entertainment/Visual Art & Design']
# []
# ['/People & Society/Social Issues & Advocacy', '/Science/Earth Sciences']
# ['/Finance', '/Business & Industrial/Business Finance']
# []
# ['/Business & Industrial/Energy & Utilities', '/News/Business News/Company News']
# ['/Sports/Team Sports']
# ['/Finance', '/Business & Industrial']
# ['/Finance/Banking', '/Finance/Investing']
# ['/Business & Industrial/Business Finance', '/Finance/Banking']
# []
# ['/Finance/Banking', '/Finance/Investing']
# ['/Sensitive Subjects']
# ['/Business & Industrial', '/Finance']
# ['/Business & Industrial', '/People & Society']
# ['/Business & Industrial/Business Finance', '/Law & Government/Government']
# ['/Business & Industrial', '/Finance/Banking']
# ['/People & Society/Social Issues & Advocacy/Green Living & Environmental Issues']
# ['/Business & Industrial', '/News/Business News']
# ['/Business & Industrial/Business Finance', '/Finance']
# ['/Finance/Banking']

# %%
for key, value in news_json.items():
    print(value['entities'])
# Out:
# ['women', 'Christiana', 'list', 'workplace', 'change', 'gender diversity', 'example', 'HERoes 100 Women Executives', 'Felix', 'Christiana Riley', 'women', 'Americas', 'spot', 'spotlight', 'executives', 'workplace', 'business achievements', 'President', 'impact', 'influence', 'role', 'nominee', 'HERoes', 'Christiana', 'Chairwoman', 'Executive Vice-Chairman', 'accolade', 'panel', 'workplace', 'region', 'gender equality objectives', 'one', 'Capital One Canada', 'Jennifer Jackson', 'Ann Cairns', 'Mastercard', 'IG Group', 'Masami Katakura', 'EY ShinNihon', 'people', 'CEO', 'woman', 'inclusion', 'history', 'Financial Times', 'Wall Street', 'Deutsche Bank', '2020', 'One', '5', 'one', '100', '100', '2020', '150']
# ['Ambrosi SpA', 'Italian', 'company', 'loan', 'Deutsche Bank', 'Italy', 'DOP cheeses', 'syndicate banks', 'process', 'production', 'ageing', 'Brescia Group', 'Parmigiano Reggiano', 'Banco BPM', 'Grana Padano', 'parmesan cheese', 'bank', 'first', 'loan', 'revenues', 'asset', 'cheeses', 'cheeses', 'customers', 'inventory', 'property', 'market', 'products', 'cheeses', 'company', 'total', 'commitment', 'open market', 'loan', 'producers', 'export market', 'world', 'cheese wheels', 'wheel', 'proceeds', 'group', 'foreign bank', 'facility', 'cheese production capacity', 'province', 'headquarters', 'prices', 'ability', 'world class', 'companies', 'company', 'distributors', 'share', 'countries', 'exports', 'Ambrosi', 'all', 'sales', 'supermarkets', 'relationship', 'coronavirus crisis', 'companies', 'Brescia', 'Germany', 'thanks', 'Lombardy', 'commitment', 'business', 'phases', 'announcement', 'emergency', 'some', 'group', 'proof', 'Covid', 'branches', 'catering activities', 'restrictions', 'turnover', 'increase', 'Covid-19', 'United Kingdom', 'France', 'US', '1942', '2019', '2020', '27.5 million euros', '740 euros', '440 million euros', '46', '5', '2019', '440 million', '60', '27.5 million', '120,000', '2020', '20', '10', 'two', '19', '740', 'one', '1942', 'six', '19', '550']
# ['Deutsche Bank', 'statements', 'Net Zero Banking Alliance', 'Christian Sewing', 'NZBA', 'GFNAZ', 'group', 'banks', 'creation', 'DB', 'DBKGn.DB', 'commitment', 'portfolios', 'NYSE', 'XETRA', 'emissions', 'countries', 'part', 'finance initiatives', 'pathways', 'Glasgow Financial Alliance for Net Zero', 'Banks', 'factors', 'United Nations Environment Programme Finance Initiative', 'economy', 'bank', 'portfolio net', 'bank', 'bond', 'action', 'member', 'carbon', 'emissions', 'goals', 'climate change', 'number', 'forum', 'trillions', 'fight', 'CEO', 'latest', 'conditions', 'financing', 'investment', 'lending portfolios', 'signatory', 'statements', 'bond', 'bonds', 'alliance', 'sustainability', 'sustainability', 'actions', 'target', 'target', 'event', 'targets', 'statement', 'products', 'hedging transaction', 'Email', 'sector', 'Email', 'Email', 'clients', 'goal', 'arranger', 'progress', 'governance', 'information', 'ESG', 'opinion', 'hedge framework', 'issuer', 'conference', 'Paris Agreement', 'work', 'priority', 'operations', 'investor clients', 'factors', 'portion', 'portion', 'risks', 'space', 'Media Relations', 'management', 'role', 'role', 'details', 'events', 'information', 'any', 'markets', 'assumptions', 'Sustainability Deep Dive', 'Commitment on Climate Action', 'Germany', 'obligation', 'light', 'nature', 'uncertainties', 'results', 'elsewhere', 'banking', 'investment banking', 'banking', 'risks', 'Charlie Olivier', 'assets', 'initiatives', 'US', 'DB Access', 'German', 'DWS', 'trading counterparties', 'detail', 'facts', 'Tim-Oliver Ambrosius', 'Dylan Riddle', 'statements', 'DB Research', 'methods', 'revenues', 'procedures', 'development', 'risk management policies', 'asset prices', 'market volatility', 'filings', 'reliability', 'defaults', 'borrowers', 'implementation', 'request', 'document', 'Copies', 'release', 'investors', 'Risk Factors', 'asset', 'wealth management', 'U.S. Securities and Exchange Commission', 'governments', 'corporate', 'corporations', 'lending', 'transaction', 'individuals', 'services', 'companies', 'network', 'roots', 'beliefs', 'expectations', 'projections', 'plans', 'estimates', 'products', 'European', '+44 7917151627', '2050', '2050', '2019', 'May 2020', '2025', '2020', 'June 2020', 'March 2021', '2021', 'March 2021', 'June 2020', 'May 2021', '21 March 2021', '200 billion euros', '46 billion euros', '20 billion euro', '7917151627', '2020', 'zero', '2021', '43', '2021', '2020', '46 billion', '2021', 'zero', 'zero', '2050', 'zero', '200 billion', 'one', 'Zero', 'Zero', '2020', '2021', '+44', '2019', '23', '2025', '2021', '2020', '2050', '5', '20 billion', '20', '21']
# ['Deutsche Bank', 'State Administration of Foreign Exchange', 'bank', 'currency payments', 'trades', 'Payments for Trade', 'bank', 'Pilot Scheme for Facilitation of Foreign Exchange Receipts', 'Aptiv', 'clients', 'scheme', 'testimony', 'European', 'currency payment', 'foreign exchange payments', 'currency trade payment', 'currency payment', 'China', 'Shanghai Branch', 'banks', 'investment banking', 'retail banking', 'transaction banking', 'payment processing', 'payment procedure', 'pilot scheme', 'Alvin Ho', 'Jerry Chen', 'client', 'payments', 'Deutsche Bank Securities Inc.', 'front', 'instruction', 'documents', 'one', 'process', 'currency trade payments pilot scheme', 'corporates', 'pilot solution', 'clients', 'clients', 'Lending', 'process', 'trade account pilot solutions', 'payment solutions', 'commitment', 'commitment', 'pilot scheme services', 'banking', 'authority', 'authorization', 'benefits', 'services', 'wealth management', 'regulation', 'regulation', 'regulation', 'capital account', 'professionalism', 'payment cycle', 'market expertise', 'banking partner', 'information technology capabilities', 'asset', 'Prudential Regulation Authority', 'Financial Conduct Authority', 'Asia Pacific', 'products', 'DB', 'Banking Law', 'extent', 'Corporate Cash Management', 'Shanghai', 'Details', 'BaFin - Federal Financial Supervisory Authority', 'broker-dealer affiliates', 'banking affiliates', 'investment banking activities', 'Securities', 'activities', 'request', 'member', 'C', 'Copyright', 'German', 'United States', 'investors', 'corporations', 'affiliates', 'presence', 'individuals', 'governments', 'businesses', 'position', 'subsidiaries', 'NYSE', 'SIPC', 'NASD', 'press release', 'Germany', 'Europe', 'Americas', 'September 30', '2020', 'one', '30', 'one', '2020']
# ['governments', 'currency bond issuance', 'debt capital markets', 'interest rates', 'recovery', 'funds', 'record levels', 'activity', 'companies', 'Asian', 'The New Year', 'markets', 'issuers', 'combination', 'Deutsche Bank', 'growth', 'investors', 'issuance', 'Reuters', 'debt maturities', 'investors', 'clients', 'United States', 'Debt', 'debt', 'money', 'debt', 'market', 'issuers', 'Capital Markets', 'issuance', 'funding', 'head', 'rates', 'trade recommendation', 'maturities', 'landmark volume', 'volume', 'Vishal Goenka', 'debt syndicate', 'funding window', 'demand', 'appetite', 'Republic of Indonesia', 'rates', 'APAC', 'dollar', 'currencies', 'region', 'bond yields', 'APAC Head', 'weakening', 'outlook', 'credit spreads', 'team', 'Tsui', 'Haitham Ghattas', 'region', 'clients', 'combination', 'credits', 'credit sales', 'debt', 'capital', 'APAC Capital Markets', 'ICG APAC', 'offerings', 'differential', 'way', 'election outcome', 'stimulus', 'factors', 'investors', 'Europe', 'vaccine rollout', '2021', '3 billion US dollar', '1 billion euro', 'USD 12bn', '4', '12bn', '1 billion', '3 billion', '14', '2021']
# ['Europe', 'economy', 'pleasure', 'sector', 'indication', 'securitisation market', 'economy', 'London', 'customers', 'Ladies', 'gentlemen', 'trends', 'sustainability', 'US', 'challenge', 'consensus', 'banks', 'transformation', 'industry', 'banking industry', 'progress', 'struggle', 'capital regulations', 'time', 'ladies', 'gentlemen', 'fact', 'factors', 'technology', 'imbalance', 'many', 'crisis', 'indication', 'winners', 'scale', 'humanity', 'principle', 'banks', 'banking summit', 'clients', 'normality', 'bit', 'pandemic', 'distance', 'capital', 'upheaval', 'revolution', 'nature', 'carbon', 'catastrophe', 'scientists', 'stakes', 'course', 'industry', 'banks', 'banks', 'banking', 'banking', 'banks', 'capital market', 'banks', 'banks', 'one', 'economy', 'economy', 'banks', 'banks', 'banking', 'banks', 'core bank', 'banks', 'sector', 'sector', 'capital market', 'banking', 'banks', 'banks', 'banks', 'banks', 'banks', 'insurers', 'one', 'companies', 'companies', 'Bank of America', 'fact', 'whole', 'whole', 'credit markets', 'market', 'world', 'stock market value', 'value', 'economies', 'correlation', 'economy', 'regulation', 'banks', 'course', 'market', 'losers', 'proposition', 'location advantages', 'economy', 'condition', 'sector', 'stops', 'Deutsche Bank', 'millennium', 'decline', 'order', 'economy', 'regulation', 'investments', 'competition', 'interests', 'interests', 'interest', 'whole', 'progress', 'structures', 'consolidation', 'colleagues', 'investors', 'lever', 'bond market', 'capital markets union', 'world', 'importance', 'world', 'stock market value', 'return', 'return', 'conditions', 'Germany', 'advice', 'bank', 'banking', 'bank', 'mistake', 'business', 'scale', 'techs', 'returns', 'size', 'cost pressure', 'face', 'services', 'capital markets union', 'profitability', 'crisis', 'profit', 'business areas', 'propositions', 'importance', 'level', 'playing field', 'financing', 'services', 'preserve', 'face', 'loans', 'course', 'path', 'business', 'companies', 'deal', 'roots', 'efficiency gains', 'capital market deficit', 'leader', 'Sustainability', 'experience', 'discrepancies', 'track', 'institutions', 'point', 'equity', 'result', 'line', 'target', 'goals', 'players', 'headquarters', 'investments', 'Sustainability', 'investors', 'consolidation', 'market share', 'whole', 'gentlemen', 'borders', 'barriers', 'room', 'bank balance sheets', 'manoeuvre', 'non-banks', 'groups', 'interest rates', 'path', 'Ladies', 'China', 'technology', 'change', 'transactions', 'advice', 'transformation', 'importance', 'structure', 'climate change', 'JP Morgan', 'economy', 'use', 'business', 'conditions', 'areas', 'bonds', 'loans', 'governance', 'risk management', 'dialogue', 'topic', 'leap', 'business field', 'banking', 'prospects', 'regulation', 'banks', 'industry', 'more', 'industries', 'standards', 'validation', 'demand', 'lot', 'each', 'divisions', 'potential', 'banking sector', 'sustainability', 'dialogue', 'increase', 'twenties', 'course', 'conditions', 'Ladies', 'gentlemen', 'advantage', 'asset', 'advice', 'benchmark', 'culture', 'leadership culture', 'people', 'management', 'challenges', 'Basel IV', 'sectors', 'banking sector', 'network', 'society', 'purpose', 'focus', 'work', 'teams', 'view', 'strategy', 'attitude', 'regulation', 'regulation', 'regulation', 'people', 'constellations', 'competition', 'growth topic', 'consolidation', 'sustainability', 'investments', 'opportunity', 'duty', 'climate change', 'financing volume', 'losers', 'winners', 'humanity', 'governance', 'share', 'banking system', 'elsewhere', 'No one', 'stability', 'way', 'criteria', 'estimates', 'calculations', 'ESG', 'Autonomous', '2000', '2015', '2022', '2050', '2.8 billion euros', '3.4 billion euros', '20', 'one', '3.4 billion', '100', '6.5', '21', 'one', '25', '18', 'one', '25', '41', '2015', 'six', 'one', 'two', '2000', '2.8 billion', '9.3', '2050', 'two', 'one', '15', '15', 'one', 'one', '2022', 'three']
# ['Deutsche Bank', 'Luc Mériochaud', 'finalists', 'applications', 'blockchain', 'users', 'Nuggets', 'e-commerce payments', 'pitch', 'winner', 'Female FinTech Competition', 'payment', 'female(s)', 'details', 'ID platform', 'data breaches', 'winner', 'Atos', 'competition', 'finalists', 'women', 'competition', 'companies', 'FinTechs', 'services', 'data', 'founder', 'business case', 'management groups', 'study', 'UK', 'access', 'study', 'security', 'privacy', 'payments', 'finalists', 'companies', 'Gender diversity', 'women', 'gender diversity', 'women', 'each', 'group', 'startup founders', 'pitches', 'business case', 'plenty', 'potential', 'space', 'place', 'programme', 'benefit', 'resources', 'TechQuartier', 'Google Cloud', 'end', 'opportunities', 'funding', 'sector', 'population', 'gender diversity results', 'evidence', 'Judges', 'investment banking', 'banking', 'banking', 'France', 'relative', 'companies', 'Google Innovation', 'corporate', 'services', 'corporations', 'Deloitte', 'investors', 'wealth management', 'network', '7%', 'Cloud Germany', 'Google', 'lending', 'governments', 'transaction', 'individuals', 'asset', 'roots', 'Global Head of Innovation Network', 'Head of Innovation Products', 'products', 'finalists', 'Finalists', 'Germany', 'Italy', 'Serena Torielli -- Virtual B', 'Annie Guo -- Silkpay', 'USA', 'Nerissa Naidu-- Axil', 'Corporate Venture Capital', 'AtoS Central Europe', 'HRD', 'Ozlum Yavus', 'MD', 'Annette Maier', 'Lucas Schmitt', 'competition', 'products', 'services', 'judges', 'hope', 'women', 'ideas', 'market', 'levels', 'role models', 'list', 'Tech Quartier', 'European', 'Seema Khinda Johnson -- Nuggets', 'Franca Perin -- IMPACTIN', 'Iwona Pawlak', 'Smart Forest', 'Poland', 'talent', '2020', '2019', '7', 'six', '1.3', '2020', '2019', 'two', 'six', '43', 'one', 'one']
# ['Emergency Credit Line Guarantee Scheme', 'MSME', 'relief package', 'clients', 'credit', 'Deutsche Bank', 'pandemic', 'Government of India', 'sector', 'clients', 'part', 'Indian', 'loans', 'Cash flows', 'project effort', 'Amit Bhatia', 'Clients', 'government', 'term loan', 'credit guarantee', 'form', 'moratorium', "Daryl D'Souza", 'government', 'clients', 'loan', 'times', 'part', 'interest', 'pandemic', 'sector', 'solution', 'goods', 'supply chains', 'disruption', 'demand', 'services', 'initiative', 'liabilities', 'ECLGS', 'amount', 'installments', 'businesses', 'scheme', 'Business', 'most', 'Lending', 'products', 'department', 'tandem', 'Sales', 'government', 'Head of International Private Bank', 'Atmanirbhar Bharat', 'COVID', 'people', 'country', 'Links', 'times', 'Risk', 'offering', 'efforts', 'solution', 'road', 'core', 'system changes', 'hurdles', 'processing requirements', 'documentation protocols', 'stone', 'May 2020', 'October 31', 'November 30', '12 billion Indian rupees', '138 million euros', '63 million', '19', '2,000', '2020', '12', '110 million', '100', '31', '30', '36', '138 million', '12 billion']
# ['loss', 'profit', 'credit loss provisions', 'rise', 'restructuring', 'Christian Sewing', 'loss', 'profit', 'profit', 'Group', 'credit losses', 'Provision', 'management expectations', 'costs', 'effects', 'loss', 'loans', 'basis points', 'guidance', 'revenues', 'revenues', 'profit', 'profit', 'revenues', 'Core Bank', 'costs', 'Noninterest expenses', 'Prime Finance expenses', 'Equities', 'items', 'equity', 'Revenue growth', 'items', 'progress', 'progress', 'exit', 'earnings momentum', 'return', 'revenues', 'Investment Bank', 'costs', 'targets', 'credit losses', 'partnership', 'agreement', 'Chief Executive Officer', 'environment', 'track', 'provision', 'growth', 'clients', 'conditions', 'capital position', 'resilience', 'Corporate Bank', 'Google Cloud', 'Integration', 'scope', 'transformation', 'investment', 'financing', 'target', 'entity merger', 'Private Bank', 'International Private Bank', 'Germany', 'Wealth Management and Private & Commercial Business International', '2019', '158 million euros', '946 million euros', '61 million euros', '3.1 billion euros', '761 million euros', '753 million euros', '489 million euros', '6.3 billion euros', '6.4 billion euros', '6.3 billion euros', '5.4 billion euros', '4.8 billion euros', '200 billion euro', '761 million', '3.1 billion', '158 million', '2', '489 million', '61 million', '3.4', '6.4 billion', '8', '6.3 billion', '5.4 billion', '2', '52', '753 million', '46', '1', '6.3 billion', '4.8 billion', '6', '200 billion', '45', '23', '946 million', '35', '10', '2019']
# ['Deutsche Bank', 'upgrade', "Moody's Investors Service", 'review', 'ratings', 'review', 'bank', 'agency', 'capital', 'success', 'James von Moltke', 'Credit quality', 'account', 'rating action', 'progress', 'liquidity', 'possibility', 'timeframe', 'buffers', 'business model', 'objective', 'overhaul', 'move', 'ratings', 'rating agencies', 'outlook upgrades', 'earnings strength', 'transformation', 'bank', 'factors', 'agency', 'sustainability', 'capital ratios', 'execution', 'balance sheet management', 'priority', 'stakeholders', 'transformation strategy', 'Earnings strength', 'upgrade', 'upgrade', 'agency', 'sustainability', 'transformation', 'transformation', 'recognition', 'financing transformation', 'bank', 'bank', 'discipline', 'respect', 'review', 'markets', 'progress', 'capital', 'ratings', 'Investment Bank', 'overhaul', 'self-finance', 'risk management', 'investment', 'revenues', 'execution', 'capital markets', 'earnings', 'Private Bank', 'Corporate Bank', 'revenues', 'revenues', 'risk exposures', 'exposures', 'liquidity', 'earnings momentum', 'controls', 'technology', 'rating agencies', 'momentum', 'market funding', 'impact', 'dependence', 'path', 'achievements', 'part', 'loan loss provisions', 'restructuring', 'charges', 'resources', 'exposure consumption', 'operating costs', 'Moody', 'ratings outlook', 'ability', 'market environment', 'risk appetite', 'backdrop', 'interest rate headwinds', 'focus industries', 'sectors', 'loan book', 'magnitude', 'ratings', 'sustainability leader', 'stakeholders', 'sustainability strategy', 'turnaround', 'turnaround', 'upgrade', 'agencies', 'rating agencies', 'review', 'peers', 'event', 'details', 'ratings prospects', 'ratings outlook', 'outlook', 'ratings outlook', 'move', 'move', 'overview', 'ambition', 'action', 'Fitch Ratings', 'agency', 'upgrade review', 'sustainability', 'execution', 'transformation', 'factors', 'factors', 'Sustainability Deep Dive', 'controls', 'sustainability leadership', 'pandemic', 'real estate', 'aviation', 'leisure', 'profitability', 'risk management infrastructure', 'technology platform', 'digitalisation', 'S&P', 'role', '2019', 'November 2020', '&euro;7 billion', '&euro;1.8 billion', '2020', 'three', 'three', 'two', '30', '1.8 billion', 'six', 'two', '90', '2019', '7 billion', 'six']
# ['Deutsche Bank', 'GlobalCapital Asia', 'bank', 'bank', 'response', 'resilience', 'region', 'coronavirus crisis', 'test', 'business continuity', 'bank', 'pandemic', 'publication', 'clients', 'solutions', 'Investment Bank', 'line', 'focus', 'payment', 'tone', 'conditions', 'market rapidity', 'client base', 'bank', 'shareholder', 'Trans Retail Indonesia', 'Michael Connolly', 'bank', 'response', 'app', 'award', 'Amit Khattar', 'bank', 'Investment Bank', 'bank', 'bond', 'client', 'client', 'clients', 'clients', 'clients', 'challenge', 'resilience', 'back line', 'bond', 'transactions', 'kudos', 'bank', 'another', 'house', 'agility', 'front', 'people', 'platform', 'transactions', 'capital markets', 'US', 'markets', 'high yield market', 'solutions', 'equipment', 'COVID', 'clients', 'bonds', 'Crisis Response of the Year', 'AsiaRisk', 'Best COVID Response', 'CB', 'Sriram Transport', 'roles', 'part', 'themes', 'publication', 'loans', 'dollar loan', '3SBio', 'needs', 'hospitals', 'entity', 'capital injection', 'lock', 'most', 'adaptability', 'trades', 'client demand', 'increase', 'access', 'execution', 'shortage', 'funding', 'dollar liquidity support', 'liability management', 'roles', 'bond', 'bond', 'bonds', 'bond', 'ESG', 'Asia', 'India', 'China', 'result', 'loan deal categories', 'take-private', 'deal', 'APAC', 'wins', 'bank', 'APAC', 'spike', 'Best Loan', 'Best High Yield Syndicated Loan', 'Portugal', 'Portuguese', 'Autobahn', 'clients', 'clients', 'convertible bond', 'Best Leveraged/Acquisition Finance', 'teams', 'Best HY Corporate Bond', 'Best SSA Bond', 'landmark transactions', 'transactions', 'equity market', 'Hexaware Technologies', 'Baring Private Equity', 'Kaisa Group', 'Best of South Asia', 'Megatrend Deal of the Year', 'FinanceAsia Awards', 'role', 'region', 'challenges', 'shares', 'loan team', 'Republic of Indonesia', 'hit', 'solutions', "Best Project Finance Deal' for Star Energy", 'Vedanta Resource', '2020', '500 million US dollars', '740 million US dollar', '600 million US dollars', '4.3 billion US dollar', '1.4 billion US dollar', '790 million US dollar', '600 million', '4.3 billion', 'three', '790 million', 'three', '2020', '300', '740 million', '500 million', '3', '1.4 billion', 'four']
# ['report', 'Coronavirus', 'governance', 'Governance', 'impact', 'governance', 'subject', 'focus', 'firms', 'Deutsche Bank', 'International Private Bank on Environmental', 'governance', 'ESG', 'third', 'Social and Governance', 'themes', 'functions', 'governments', 'governance', 'governance changes', 'resilience', 'governance', 'effects', 'environment', 'demands', 'crisis', 'areas', 'cash flow', 'customers', 'obligations', 'scope', 'balance', 'approaches', 'workforce', 'aspects', 'firms', 'firms', 'impact', 'way', 'reports', 'performance', 'history', 'guest contribution', 'reports', 'involvement', 'governments', 'investing', 'components', 'social', 'series', 'E', 'sense', 'report', 'German', 'investors', 'governance components', 'needs', 'concerns', 'range', 'individuals', 'corporates', 'overview']
# ['Deutsche Bank', 'product', 'customers', 'Part', 'farmers', 'Farming for Climate', 'farmers', 'investment product', 'concrete', 'environment', 'Farming for Climate', 'impact', 'CCO', 'Belgian', 'transition', 'collaboration', 'farmers', 'Olivier Delfosse', 'mission', 'practices', 'profits', 'organisation', 'sale', 'bank', 'investment product', 'Deutsche Bank AG Green Note Fund Opportunity', 'transition', 'product', 'support', 'Pascal Durdu', 'clients', 'customers', 'assets', 'two', 'bank', 'profits', 'investment product', 'investments', 'investors', 'investors', 'transition', 'asset pool', 'distribution margin', 'agriculture', 'guidance', 'support', 'support', 'support', 'transition', 'part', 'customers', 'assets', 'fund', 'ecosystem', 'companies', 'region', 'production', 'colleagues', 'financing', 'financing', 'performance', 'program', 'progress', 'fund performance', 'total', 'volume', 'management', 'framework', 'portfolio', 'target', 'cash', 'gold', 'bonds', 'equities', 'maturity', 'amount', 'order', 'branch network', 'client events', 'neighborhood', 'capital', 'floor', 'project', 'sustainability objectives', 'economy', 'ESG', 'goal', 'product', 'Product', 'Agro-ecological practices', 'investors', 'chance', 'investment solutions', 'transition', 'matter', 'activity', 'soil cover', 'pesticides', 'Ploughing', 'crop rotation', 'insect habitat', 'food resilience', 'CO2 emissions', 'partner', 'water quality', 'aim', 'environment', 'soil tillage', 'biodiversity', 'facilitator', 'dynamic', 'world', 'aims', 'link', 'clients', 'results', 'role', '2031', 'December 7', '2025', '200 billion euros', '2025', '7', '10', '90', 'five', '25', '100', 'two', '200 billion', '30', '-10', '2031']
# ['clients', 'Deutsche Bank Wealth Management', 'strategies', 'bank', 'investment funds', 'investments', 'issues', 'governance', 'environment', 'International Private Bank', 'process', 'individuals', 'Germany', 'role', 'ESG', 'Christian Nolting', 'investments', 'funds', 'funds', 'returns', 'opportunities', 'investors', 'values', 'demand', 'change', 'asset allocation approach', 'investments', 'goals', 'indices', 'business', 'timing', 'fund strategies', 'provider', 'benchmarks', 'analysis', 'view', 'business practices', 'areas', 'account', 'sustainability aspects', 'data', 'sustainability', 'behaviour', 'Growth', 'risk profiles', 'fee', 'investors', 'role', 'investment tools', 'way', 'expertise', 'investors', 'Wealth Management', 'variant', 'MSCI', 'Vermögensfondsmandate', 'goals', 'return opportunities', 'Conservative', 'philanthropy', 'predecessors', 'assets', 'worth', 'IPB', 'Head of Investment Solutions', 'CIO']
# ['Deutsche Bank', 'firms', 'payment solutions', 'companies', 'development', 'payments', 'payments', 'payments', 'platforms', 'products', 'consumers', 'transactions', 'revenue growth', 'number', 'business segment', 'business clients', 'area', 'banks', 'opportunity', 'posts', 'partnership', 'innovations', 'Payments', 'payment', 'payments', 'services', 'payments', 'companies', 'Germany', 'Mastercard', 'business models', 'sales channels', 'customer demographics', 'interface', 'banks', 'payments', 'services', 'coronavirus pandemic', 'growth', 'payment solutions', 'fraud management services', 'solutions', 'payments area', 'markets', 'card issuance', 'integration', 'accounting systems', 'clients', 'presence', 'issues', 'growth segment', 'acceptance', 'merchant', 'corporates', 'demand', 'dollar payments', 'businesses', 'cash flow forecasting', 'currency hedging', 'offering', 'transactions', 'coronavirus pandemic', 'payment management system', 'revenues', 'number', 'source', 'banks', 'Payments', 'catalyst', 'banking industry', 'spectrum', 'payments', 'payment clearers', 'one', 'one', 'payments clearing', 'clearers', 'Global Head of Cash Management', 'Ole Matthiessen', 'source', 'Peter Bakenecker', 'world', 'expertise', 'McKinsey', 'shifts', 'transformation', 'companies', 'US', 'timing', 'President', 'market developments', 'joint endeavours', 'Capgemini', 'Switzerland', 'Divisional', '2023', 'one', 'six', '2023', 'one', 'six', '11', '11', 'one']
# ['priority', 'Deutsche Bank', 'laundering issues', 'number', 'media outlets', 'reports', 'authorities', 'consequence management', 'ICIJ', 'statement', 'crime', 'institutions', 'money laundering', 'information', 'capital flight', 'world', 'institutions', 'issues', 'resources', 'authorities', 'number', 'controls', 'responsibilities', 'obligations', 'risk mitigants', 'effort', 'detection levels', 'customers', 'correspondent banking relationships', 'resolutions', 'banks', 'extent', 'issues', 'alerts', 'SARs', 'governments', 'law', 'facts', 'bank', 'SARs', 'issues', 'regulators', 'remediation', 'cooperation']
# ['Risk.net', 'Deutsche Bank', 'winners', 'awards', 'publication', 'accolades', 'Bank Risk Manager of the Year', 'one', 'transformation efforts', 'Stuart Lewis', 'Risk.net', 'bank', 'bank', 'bank', 'team', 'award', 'market risk', 'pandemic', 'bank', 'story', 'response', 'innovations', 'market risk management', 'publication', 'pandemic', 'change', 'credit losses costs', 'crisis', 'peers', 'market turmoil', 'all', 'risk management capabilities', 'resilience', 'opportunities', 'resources', 'lows', 'assets', 'loan book', 'switch', 'simulation methodology', 'milestone', 'risk architecture', 'accolade', 'risk frameworks', 'challenges', 'clients', 'economy', 'everyone', 'Congratulations', 'risk management', 'award', 'market risk', 'Covid', 'derivatives', 'focus', 'industry', 'finance', 'download', 'report', 'award', 'achievement', 'calculations', 'work', 'risk disciplines', 'strength', 'CRO', 'VAR', '2021', '2014', '2020', '2019', '2020', 'one', '2019', '2021', '2014']
# ['pandemic', 'treasurers', 'treasurers', 'treasury', 'challenges', 'survey', 'strategy', 'priority lists', 'Covid-19', 'face', 'investments', 'respondents', 'Economist Intelligence Unit', 'Deutsche Bank', 'bid', 'respondents', 'results', 'survey', '48%', 'treasurers', 'Melanie Noronha', 'investments', 'investments', 'Technology', 'interest-rate risk', 'department', '38%', 'replacement', 'plan', 'business plans', 'Treasury', '69%', 'priority', 'risk', 'impacts', 'foreign-exchange', 'money-market funds', 'investment products', 'instruments', 'bank deposits', 'teams', 'challenges', 'challenge', 'challenge', 'one', 'treasurers', 'function', 'treasury skills', 'risks', 'issue', 'respondents', 'technology', '32%', 'systems', 'treasury teams', 'list', 'strain', 'report', 'skill sets', 'skills', 'henry.williams@finnpartners.com', 'level', 'data', 'change', 'wings', 'IT solutions', 'concerns', 'data quality', 'treasury processes', 'liquidity', 'treasury checklist', 'banks', 'respondents', 'survey', 'figure', 'progress', 'benefits', 'functions', 'relationships', 'partners', 'Covid', 'stakeholders', 'business', 'report', 'suppliers', 'agenda', 'insight', 'treasury executives', 'Ole Matthiessen', 'London Interbank Offered Rate', 'top', 'technology', 'priorities', 'pandemic', 'treasury function', '30%', 'change', 'stakeholders', 'bandwidth', 'focus', 'video', 'drivers', 'attitudes', 'regulation', 'findings', 'information', 'Phone', 'Corporate Bank', 'priorities', 'technology', 'role', 'environment', 'Cash Management', 'Henry Williams', '+44 20 7539 3564', '2020', '2019', '2020', '2020', '2018', '3564', '2020', '48', '78', '48', '2018', '22', '38', '2020', '19', '32', '+44', '19', '55', '30', '2020', '19', '20', 'one', 'five', '19', '7539', '32', '300', '69', '2019', '47']
# ['China', 'Deutsche Bank', 'Republic of Indonesia', 'bond', 'bond', 'bond', 'M&A', 'deals', 'magazine', 'wins', 'Best High-Yield', 'Best Formosa', 'Asset', 'North Asia', 'Country Awards', 'Taiwan', 'bond', 'sovereign', 'Ministry of Finance', 'bank', 'transaction', 'bond', 'bond', 'bond', 'India', 'bond', 'bond', 'bond', 'PepsiCo', 'strength', 'bank', 'category', 'bond', 'bond', 'bond', 'bond', 'bond', 'M&A', 'euro benchmark', 'US', 'acquisition', 'wins', 'M&A team', 'strength', 'category', 'bond', 'bond', 'bond', 'SEC', 'State of Israel', 'deal', 'home', 'advisor', 'region', 'leverage buyout financing', 'announcement', 'challenges', 'pandemic', 'MoF', 'Be & Cheery', 'bond', 'bond', 'bond', 'bond', 'China Development Bank', 'LBO - Baring Private Equity Asia USD', 'Asset Country Awards', 'APAC', 'senior notes', 'acquisition', 'State', 'Hutama Karya', 'Hexaware Technologies', 'notes', 'bond offering', 'Macau', 'Studio City Finance Limited', 'Shriram Transport Finance Company', 'Adani', 'Electricity Mumbai', 'Vedanta Resources', '3NC2', '2020', '4 billion euro', 'USD 4.3 billion', 'USD 600 million', 'USD 500 million', 'USD 1 billion', 'USD 1.4 billion', 'USD 600 million', 'EUR 4 billion', 'GBP 1 billion', 'USD 705 million', 'USD 1 billion', 'USD 5 billion', '1 billion', '1 billion', '5 billion', '4.3 billion', '2020', '600 million', '705 million', '4 billion', '5 billion', '4 billion', '705 million', '600 million', '3', '4.3 billion', '1.4 billion', '1 billion', '500 million', '600 million']
# ['Deutsche Bank', 'Provision', 'ratio', 'costs', 'Core Bank', 'Private Bank', 'Capital Release Unit', 'revenues', 'tax', 'Corporate Bank', 'investment products', 'RoTE1', 'line', 'income', 'ESG', 'profit', 'Equity', 'expenses', 'effects1', 'RoTE1', 'Germany', 'BGH', 'revenues', 'return', 'cost', 'costs', 'costs', 'cost', 'cost', 'ruling', 'ratio1', 'Business growth', 'ratio', 'ratio', 'ratio', 'profit', 'net profit', 'Group profit', 'profit', 'profit', 'Asset Management', 'revenues', 'Capital', 'tax', 'revenues', 'tax', 'loss', 'credit losses', 'profit growth', 'credit losses', 'quarter', 'income', 'markets', 'assets', 'Transformation', 'financing', 'loans', 'income', 'income', 'impact', 'target', 'business volumes', 'investment volumes', 'target', 'volumes', 'target', 'RoTE1', 'Noninterest expenses', 'inflows', 'inflows', 'half', 'RoTE1', 'effects', 'basis points', 'International Private Bank', 'charges', 'inflows', 'progress', 'risk', 'risk', 'Equity', 'RWAs', 'progress', 'Assets under Management', 'line', 'Tier', 'profit', 'Record', 'exposure', 'path', 'measures', 'measures', 'Investment Bank', 'discipline', 'balance sheet', 'outperformance', 'Data Supplement', 'Finance1', 'Use', 'businesses', 'expenses', 'cuts', 'Sustainability', 'ambitions', 'description', 'revenues', 'revenues', 'RoTE1', 'revenues', 'Revenues', 'RWAs', 'Group profit', 'profit', 'loss', 'loss', 'cost', 'cost', 'cost', 'normalisation', 'profit', 'profit', 'profit', 'cost impact', 'Bank', 'Corporate Banking', 'quarters', 'tax', 'risk management', 'businesses', 'credit losses', 'tax', 'tax', 'tax', 'tax', 'businesses', 'profit growth', 'Unit', 'Provisions', 'transformation', 'impact', 'impact', 'relevance', 'litigation expenses', 'revenues', 'revenues', 'Revenues', 'line', 'improvements', 'profit improvement', 'board profit improvement', 'cost reduction', 'Revenue development', 'bank', 'development', 'Leverage Ratio', 'record inflows', 'ruling', 'ruling', 'revenue items', 'cost', 'cost', 'loans', 'progress', 'equity', 'margin', 'loan portfolio', 'quarters', 'quarters', 'loss', 'clients', 'costs', 'balance', 'profitability', 'deposit re-pricing', 'bank', 'bank', 'bank', 'bank', 'section', 'credit losses', 'core businesses', 'return', 'tax', 'tax', 'loss', 'tax', 'tax', 'loss', 'business volumes', 'business growth', 'growth', 'growth', 'path', 'goal', 'market share', 'shareholders', 'markets', 'Emerging Markets', 'Financing', 'markets', 'Debt Capital Markets', 'end', 'priority', 'impact', 'impairments', 'target', 'target', 'Asset Management', 'noninterest expenses', 'business growth', 'business growth', 'growth', 'Growth', 'growth', 'revenue development', 'revenues', 'execution', 'information', 'Interim Report', 'accounts', 'levels', 'client loans', 'assets', 'litigation provisions', 'improvement', 'improvement', 'improvement', 'leverage', 'Unit', 'improvement', 'improvement', 'business volumes', 'currency translation effects', 'effects', 'loss reduction', 'cost reduction', 'reduction', 'reduction', 'reduction', 'effects', 'inflows', 'inflows', 'cost', 'cost', 'inflows', 'client inflows', 'Noninterest expenses', 'ruling', 'items', 'support', 'revenue items', 'transformation charges', 'revenue items', 'charges', 'record level', 'progress', 'foundations', 'Leverage Ratio', 'ratios', 'Chief Executive Officer', 'cost reduction', 'ratio', 'leverage ratio', 'ratio', 'target ratios', 'pricing changes', 'bank', 'German', 'profitability', 'items', 'charges', 'interest rates', 'rebalancing actions', 'factors', 'Rates', 'market activity', 'M&A activity', 'half', 'bank', 'bank', 'investments', 'bank', 'bank', 'investment products', 'investment products', 'investment products', 'equivalents', 'portfolio', 'deposits', 'businesses', 'management', 'credit losses', 'management', 'interest rates', 'increase', 'factors', 'business growth', 'revenue growth', 'income', 'income', 'normalisation', 'loans', 'Advisory', 'exposure', 'leverage exposure', 'market normalisation', 'pressur ...
# ['Volkswagen', 'antisemitism', 'Daimler', 'society', 'antisemitism', 'companies', 'Deutsche Bahn', 'Germany', 'IHRA', 'Deutsche Bank', 'declaration', 'Borussia Dortmund', 'decision', 'companies', 'Freundeskreis', 'Yad Vashem e.V.', 'employees', 'raw material', 'racism', 'antisemitism', 'racism', 'responsibility', 'diversity', 'commemoration event', 'commemoration event', 'declaration', 'declaration', 'definition', 'Freundeskreis Yad Vashem e.V.', 'signal', 'freedom', 'democracy', 'Participants', 'presidency', 'coexistence', 'cooperation', 'hope', 'Josef Schuster', 'Michaela Küchler', 'commemoration', 'International Holocaust Remembrance Day', 'society', 'people', 'principles', 'order', 'companies', 'racism', 'contributions', 'stand', 'stand', 'Yad Vashem', 'Walter Lübcke', 'place', 'event', 'antisemitism', 'German', 'antisemitism', 'companies', 'fight', 'remembrance', 'society', 'society', 'antisemitism', 'society', 'organizations', 'President', 'culture', 'racism', 'racism', 'society', 'companies', 'history', 'racism', 'responsibility', 'respect', 'situation', 'consideration', 'Chair', 'representatives', 'guests', 'government', 'respect', 'commitment', 'humanity', 'crimes', 'suit', 'values', 'employees', 'extremist', 'integration', 'employees', 'integration', 'diversity', 'people', 'responsibility', 'extremism', 'integration', 'extremism', 'examples', 'values', 'tolerance', 'working definition', 'Germans', 'opportunity', 'tolerance', 'opportunities', 'value', 'opportunity', 'declaration', 'Racism', 'views', 'initiatives', 'donation initiative', 'development', 'freedom', 'voice', 'organisations', 'training', 'development', 'National Socialism', 'people', 'end', 'range', 'foothold', 'increase', 'concern', 'assassination', 'synagogue', 'advocates', 'peace', 'groups', 'Jews', 'openness', 'ideas', 'levels', 'recruitment', 'positions', 'another', 'cohesion', 'place', 'diversity', 'employees', 'murders', 'attack', 'Diversity', 'human dignity', 'brutalization', 'populism', 'soccer pitch', 'distances', 'hate', 'future', 'solidarity', 'contribution', 'contribution', 'COVID', 'Central Council of Jews', 'commitment', 'tolerance', 'hatred', 'hatred', 'companies', 'duty', 'participation', 'democracy', 'workforce', 'culture', 'incitement', 'trainees', 'voice', 'stance', 'Holocaust', 'sign', 'lessons', 'environment', 'exclusion', 'behavior', 'liberation', 'programme', 'ideology', 'extremism', 'commemoration event', 'world', 'definition', 'world', 'antisemitism', 'film', 'Halle', 'Hanau', 'responsibility', 'society', 'viewing', 'Hans-Joachim Watzke', 'Richard Lutz', 'European', 'racism', 'racism', 'company', 'role', 'forms', 'discrimination', 'statements', 'website', 'www.yad-vashem.de', 'www.yad-vashem.de', 'stand', 'Auschwitz.', 'diversity', 'Gunnar Kilian', 'world', 'hatred', 'place', 'incitement', 'duty', 'individuals', 'basis', 'faith', 'orientation', 'gender', 'skin color', 'origin', 'worst', 'Crises', 'best', 'Kai Diekmann', 'Ola Källenius', 'Paul Achleitner', 'March 2021', 'January 26', 'April 2019', 'January 26', 'five', '26', '2021', 'one', '19', '200', '26', 'One', '2019', '76', 'five']
# ['bank', 'business agility', 'aspiration', 'element', 'technology strategy', 'teams', 'business agility', 'business', 'technology', 'clients', 'hallmark', 'solutions', 'efficiency', 'credit', 'One Bank', 'business impact', 'teams', 'Deutsche Bank', 'International Bank Lending Tribe', 'teams', 'winners', 'Transformation Factory', 'working environment', 'bank', 'bank', 'category', 'bank', 'solution', 'Agile@DB', 'Group Agility Awards', 'Employees', 'idea box', 'clients', 'categories', 'resonance', 'Technology Infrastructure', 'Agile', 'messaging services', 'votes', 'employee crowd voting', 'corners', 'journey', 'globe', 'progress', 'competition', 'colleagues', 'award ceremony', 'pitching', 'expectations', 'organisation', 'entries', 'Client User Value', 'Michael Ilgner', 'Bernd Leukert', 'lending system', 'transformation', 'examples', 'Team', "People's Choice Award", 'architecture', 'releases', 'One Symphony', 'system', 'euro revenue growth', 'Symphony WeChat', 'WhatsApp CONNECT', 'division', 'euro benefits', 'trade processing', 'change ideas', 'paradigm shift', 'FX Risk Management System', 'employees', 'FX', 'citizen innovation', 'Ways', 'Rapid Quality Delivery', 'RMS', 'Great Working Environment -- Team', "What'sApp", 'Americas Idea Box', 'four', '15,000', '226', 'One', '1,400']
# ['Deutsche Bank', 'profit', 'Core Bank', 'quarters', 'loans', 'profitability', 'Provision', 'Corporate Bank', 'tax', 'Capital Release Unit', 'transformation', 'impact', 'revenues', 'sale', 'Revenue growth', 'tax', 'tax', 'Chief Executive Officer', 'revenues', 'revenues', 'credit losses', 'net profit', 'profit', 'profit', 'tax', 'profit', 'Private Bank', 'loss', 'tax', 'loss', 'tax', 'credit losses', 'tax', 'tax', 'Cost reduction', 'transformation', 'growth', 'quarter', 'assets', 'capital', 'Prime Finance', 'costs', 'costs', 'management', 'assets', 'target', 'Noninterest expenses', 'target', 'reimbursable expenses', 'charges1', 'reductions', 'basis points', 'profit', 'ratio', 'risk', 'Group', 'Revenues', 'progress', 'Leverage exposure', 'Liquidity reserves', 'Christian Sewing', 'items1', 'impact', 'bank levies', 'de-risking', 'balance sheet', 'Tier', 'Equity', 'items1', 'quarters', 'reduction', 'Asset Management', 'description', 'Advisory', 'line', 'loss', 'profit', 'profit', 'profit', 'profit', 'COVID-19', 'Investment Bank', 'items1', 'profit', 'profitability', 'profit', 'Commercial Banking', 'credit losses', 'loss', 'loss', 'loss', 'euro loss', 'transformation', 'transformation', 'transformation', 'ESG', 'liquidity reserves', 'profit growth', 'Revenue growth', 'profit growth', 'profit growth', 'Bank', 'Revenue growth', 'capital', 'quarters', 'Unit', 'costs', 'foundations', 'credit provisions', 'provisions', 'provisions', 'profit', 'goodwill impairments', 'effects', 'expectations', 'clients', 'tax effects', 'Revenues', 'loss', 'release', 'requirements', 'trend', 'revenues', 'revenues', 'bank', 'loss', 'losses', 'loss', 'loss', 'clients', 'bank', 'execution', 'currency translation', 'revenues', 'Revenue growth', 'revenue impact', 'impact', 'bank', 'severance charges', 'impairments', 'assets', 'impact', 'tax assets', 'Postbank Systems', 'client financing', 'costs1', 'Assets', 'assets', 'growth', 'growth', 'impact', 'business growth', 'impact', 'measures', 'measures', 'capital', 'costs', 'basis', 'currency translation effects', 'currency translation effects', 'Leverage Ratio', 'transformation charges', 'noninterest expenses', 'reduction', 'reduction', 'Unit', 'reduction', 'target', 'Use', 'sale', 'items1', 'items1', 'items', 'plans', 'revenue items', 'TRIM', 'client loans', 'Credit', 'pandemic', 'times', 'objectives', 'track', 'payments', 'tax benefit', 'International Private Bank', 'sale', 'deposits', 'Currencies', 'risk', 'inflows', 'Transformation charges1', 'businesses', 'progress', 'guidance', 'execution', 'debt capital markets', 'Emerging Markets', 'risk', 'provision', 'bank', 'bank', 'bank', 'impact', 'impact', 'growth', 'capital', 'half', 'interest rate headwinds', 'half', 'Leverage exposure', 'half', 'exposure', 'development', 'Origination', 'Investment Grade Debt Origination', 'Origination', 'costs', 'basis', 'Provision', 'loans', 'loans', 'provisions', 'interest rate headwinds', 'investment products', 'deposit repricing', 'plan', 'part', 'increase', 'goodwill', 'severance', 'de-risking', 'Group results', 'charges', 'revenues', 'European Central Bank', 'basis points', 'basis points', 'basis points', 'basis points', 'basis points', 'basis points', 'FIC', 'source', 'rise', 'rise', 'source', 'results', 'value', 'revenues', 'revenues', 'Transaction Banking revenues', 'revenues', 'ratio', 'Leverage Ratio', 'risk Management needs', 'deposit re-pricing', 'DBKGn.DB', 'restructuring', 'intangibles', 'liquidity', 'revenues', 'increase', 'revenues', 'revenues', 'media release', 'Germany', 'guidance', 'guidance', 'guidance', 'progress', 'businesses', 'central bank deposit balances', 'balances', 'market conditions', 'market share gains', 'discipline', 'accounts', 'deposit repricing agreements', 'Assets', 'NYSE', 'XETRA', 'increases', 'basis', 'financing', 'financing', 'financing', 'finance', 'Sales & Trading', 'FIC Sales & Trading', 'investment', 'investing', 'Management', 'loans', 'risk management framework', 'balance sheet', 'cont ...
# ['Deutsche Bank', 'franchise', 'Best International Investment Bank', 'Indonesia', 'Siantoro Goeyardi', 'debt capital markets', 'strength', 'Finance Asia Country Awards', 'M&A advisory', 'markets', 'strength', 'trading', 'debt capital markets', 'commitment', 'fixed income markets', 'one', 'M&A', 'adviser', 'strength', 'banks', 'M&A transactions', 'teamwork', 'corporates', 'transaction value', 'relationships', 'structuring', 'debt issuances', 'market makers', 'clients', 'one', 'Bonds', 'bond', 'three', 'Southeast Asia', 'investors', 'foreign exchange hedging tool', 'corporates', 'franchise', 'clients', 'team', 'Best Main Dealer of the Year', 'DNDF', 'challenge', 'no other', 'market', 'Domestic Non Deliverable Forwards', 'investors', 'traders', 'proponent', 'rates', 'credit story', 'Indonesia Rupiah', 'FX', '2021', '2020', '2020', 'USD 4 billion', 'one', 'one', '2021', '4 billion', 'two', '2020', '2020', 'three']
# ['bank', 'Deutsche Bank', 'LGBTQ', 'immigrants', 'bank', 'home countries', 'persecution', 'asylum', 'Sarah Levitt', 'work', 'brutality', 'immigrant rights organisation', 'fight', 'Safe Haven Corporate Award', 'Immigration Equality', 'assistance', 'US', 'Joe Salama', 'volunteers', 'award ceremony', 'opportunity', 'asylum', 'people', 'colleagues', 'partnership', 'many', 'charge', 'cases', 'team', 'departments', 'efforts', 'individuals', 'banking', 'banking', 'award', 'part', 'Interim General Counsel', 'persecution', 'something', 'impact', 'colleagues', 'world', 'advocates', 'lives', 'job', 'refugees', 'discrimination', 'investment banking', 'injustices', 'abuse', 'violence', 'injustices', 'New York', 'work', 'corporate', 'advocacy', 'LGBTQ rights', 'all', 'hundreds', 'activism', 'track record', 'transaction', 'asset', 'lending', 'corporations', 'Americas', 'Global Head of Litigation and Regulatory Enforcement', 'investors', 'individuals', 'services', 'governments', 'companies', 'wealth management', 'roots', 'network', 'Links', 'Inclusion', 'Diversity', 'dbPride', 'persecution', 'countries', 'products', 'world', 'orientation', 'gender identity', 'HIV status', 'more', 'supporters', 'attorneys', 'dedication', 'Germany', 'European', 'Amicus Curiae Briefs', 'Safe Haven Awards', '2018', '1994', '80', '2018', 'four', 'three', '1994', 'seven']
# ['Deutsche Bank', 'track record', 'US', 'tranches', 'team', 'debt', 'capital market activity', 'issue', 'Record demand', 'demand', 'bank', 'Treasuries', 'Dixit Joshi', 'stakeholders', 'debt', 'debt', 'issuance', 'dollar market conditions', 'Treasury Issuance', 'rates', 'Demand', 'demand', 'issuances', 'issuance demand', 'bank', 'issuance', 'issuance', 'recognition', 'investors', 'transformation', 'instrument', 'instrument', 'order book', 'issuance', 'backdrop', 'class', 'issuance', 'demand', 'demand', 'demand', 'Orders', 'rating agencies', 'delivery', 'performance', 'analysts', 'dollar', 'bank', 'progress', 'orders', 'basis points', 'markets', 'debt', 'basis points', 'instrument', 'instrument', 'basis points', 'basis points', 'investors', 'investors', 'investors', 'pricing', 'order book', 'issues', 'bank', 'record demand', 'quality', 'class', 'advantage', 'string', 'successes', 'back', 'order book', 'capital', 'peers', 'improvement', 'discount', 'number', 'paper', 'region', 'clients', 'capital strength', 'Tier', 'success', 'gap', 'capital', 'bank', 'funding plan', 'ability', 'environment', 'recognition', 'Asia', 'transformation', 'capital markets', 'balance sheet strength', 'clients', 'progress', 'Asia-Pacific', 'Asian', 'quantity', 'demand', 'funding costs', 'form', 'world', 'support', 'Tier 2', 'benefits', 'transactions', 'string', 'Treasury Issuance Team', 'capital raisings', 'currencies', 'total', '2021', '2021', '2021', '2021', '1 billion dollars', '1.5 billion dollars', '4 billion dollars', '8 billion dollars', '700 million dollars', '11 billion euros', '35 billion euros', '148', '11 billion', '1', 'two', 'eleven', '2021', 'ten', '280', '2021', 'nine', '1.5 billion', 'three', '3', '4 billion', '50', '2021', '70', '2', 'eight', '8 billion', '20', '700 million', '1 billion', '35 billion', '287', '400', '60', '2021']
# ...
# ['step challenge', 'pandemic', 'Deutsche Bank', 'people', 'steps', 'charities', 'employees', 'success', 'NotAlone US Steps Challenge', 'US', 'steps', 'support', 'youth mental health', 'impact', 'people', 'mental health supports', 'employees', 'people', 'challenge', 'campaign', 'amount', 'The Door', 'Covid', 'family members', 'people', 'steps', 'organisations', 'mental health', 'mental health', 'parents', 'people', 'Matt Kudish', 'Kelsey Louie', 'step', 'steps challenge', 'steps', 'Contributions', 'funding', 'impact', 'lives', 'lockdown', 'Thanks', 'employees', 'mental health challenges', 'challenge', 'world', 'helplines', 'abuse', 'thoughts', 'support', 'steps', 'partners', 'lockdown', 'education', 'illness', 'challenge', 'steps', 'youth', 'donation', 'advocacy', 'staff', 'education programme', 'mental health conditions', 'students', 'communities', 'individuals', 'dependents', 'Basics class', 'number', 'caregivers', 'graduates', 'life', 'capacity', 'areas', 'families', 'signs', 'services', 'health', 'message', 'campaign', 'Many', 'milestones', 'NAMI', 'part', 'teams', 'everyone', 'NAMI-NYC', 'many', 'Ending the Silence', 'National Alliance on Mental Illness', 'Renee McConey', 'wellbeing', 'exercise', 'walking', 'opportunity', 'fact', 'participant', 'mental health support', 'people', 'funding', 'independence', 'likelihood', 'barriers', 'Adolescent Health Services', '100,000 US dollars', '50 million', '1,200', '4,456', '92 million', '20', 'One', '10,000', '100,000', '1,200', '79']
# ['coverage model', 'FIC', 'clients', 'Deutsche Bank', 'coverage model', 'fixed income markets', 'needs', 'behaviors', 'Sales team', 'Currencies', 'clients', 'clients', 'expertise', 'flow products', 'coverage access', 'approach', 'Rates', 'Credit', 'model', 'market liquidity access', 'market', 'Europe', 'changes', 'model', 'coverage channels', 'client', 'James Davies', 'client needs', 'approach', 'Panos Stergiou - Global Head', 'efficiency', 'regulation', 'technology', 'coverage', 'channel liquidity', 'Clients', 'liquidity', 'models', 'Flow Liquidity Sales', 'salesforce', 'coverage', 'position', 'cost', 'present', 'sophistication', 'channels', 'solutions', 'client experience', 'clients', 'flow liquidity salespeople', 'client needs', 'bank', 'solutions', 'Solutions', 'content access', 'expert coverage', 'lens', 'expertise', 'Flow & Liquidity and Solutions', 'behavior', 'relationship management process', 'technology', 'efficiency', 'advice', 'client offering', 'sales force', 'workflow', 'voice', 'E', 'capabilities', 'trading', 'framework', 'order', 'consistency', 'pricing', 'client analytics', 'conversations', 'data', 'expertise', 'goals', 'market making', 'client perimeter', 'firm', 'risk transfer', 'clients', 'ICG', 'way', 'franchise', 'hand', 'advice', 'hand', 'areas', 'momentum', 'CEO', 'demand', 'Liquidity focus', 'support', 'solutions', 'expertise', 'products', 'regulation', 'franchise', 'coverage model', 'backdrop', 'market share', 'IP', 'economies', 'scale', 'client partnerships', 'legacy', 'IB Americas', 'client needs', 'Head', 'products', 'way', 'service', 'competitors', 'quality', 'shift', 'ICG Macro Sales', 'ICG Debt EMEA', 'two', 'two']
# ['economy', 'resources', 'economy', 'oceans', 'world', 'land', 'estimates', 'show', 'report', 'World Wide Fund for Nature', 'situation', 'report', 'importance', 'power', 'concept', 'Chief Investment Office', 'oceans', 'resource', 'biodiversity', 'challenge', 'Wealth with Responsibility: Healing and Protecting Our Oceans', 'system', 'system', 'Chief Investment Officer', 'nature', 'International Private Bank', 'isolation', 'Deutsche Bank', 'humans', 'ecosystem services', 'investors', 'development', 'governance', 'team', 'collaboration', 'business practices', 'contributions', 'report', 'biodiversity', 'importance', 'everything', 'opportunities', 'risks', 'terms', 'some', 'world', 'Head of Investment Solutions', 'Global', 'IPB.A', 'Dasgupta Review', 'ESG', 'authorities', 'ocean conservation', 'Ocean biodiversity', 'IPB', 'specialists', 'GDP', 'times', 'returns', 'Christian Nolting', 'USD 2.5 trillion', 'USD 24.2 trillion', 'USD 125 trillion', 'USD 140 trillion', '2.5 trillion', '125 trillion', '1.5', '140 trillion', '24.2 trillion']
# ['European Commission', 'involvement', 'Green Deal', 'Deutsche Bank', 'project', 'Gerald Podobnik', 'EU', 'proposals', 'Renewed Sustainable Finance Strategy', 'Commission', 'Commission', 'Deal', 'banks', 'regulation', 'contribution', 'outcome', 'objectives', 'strategy', 'attention', 'topic', 'side-effect', 'initiatives', 'area', 'policy', 'success', 'interview', 'priorities', 'list', 'energies', 'Corporate Bank', 'programmes', 'Europe', 'framework', 'firms', 'activity', 'situation', 'economy', 'banks', 'companies', 'continent', 'loan', 'relief programmes', 'company', 'criteria', 'blue planet', 'attention', 'capacity', 'framework', 'banks', 'generations', 'course', 'matter', 'Climate developments', 'hands', 'coronavirus pandemic', 'rate', 'coronavirus relief programmes', 'financing', 'companies', 'companies', 'sustainability', 'companies', 'risk management', 'economy', 'emission', 'sector', 'capital', 'business', 'products', 'power station', 'opinion', 'objectives', 'emissions', 'economy', 'emissions', 'economy', 'transformation', 'opinion', 'plant', 'place', 'bumps', 'sectors', 'system', 'emissions targets', 'timescales', 'detail', 'target', 'example', 'example', 'sustainability', 'Banking regulators', 'Firms', 'materials', 'fossil fuels', 'world', 'work', 'lot', 'properties', 'type', 'questions', 'addition', 'biodiversity', 'standards', 'changes', 'Many', 'sustainability risks', 'incentives', 'projects', 'real estate loans', 'real estate projects', 'energy efficiency', 'recommendation', 'nuances', 'road', 'restructuring', 'practices', 'jobs', 'renewal', 'innovations', 'uniformity', 'Investments', 'capital requirements', 'states', 'investments', 'topics', 'detail', 'mortgages', 'energy certificate', 'building', 'government', 'foundations', 'discount', 'example', 'weighting', 'arenas', 'event', 'model', 'energy certificate information', 'financing', 'mortgage financing', 'risk', 'incentives', 'conditions', 'objective', 'energy efficiency', 'product', 'loan', 'product', 'potential', 'solution', 'individual', 'database', 'Greater', 'building stock', 'borrower', 'renovations', 'portfolios', 'everyone', 'contribution', 'bank', 'State Government', 'sustainability', 'Commission', 'sustainability', 'examples', 'incentives', 'incentives', 'incentives', 'Hesse', 'UK', 'definitions', 'opinion', 'energy efficiency', 'capital requirements', 'form', 'promotion factors', 'infrastructure factor', 'infrastructure', 'bubble', 'gains', 'climate risk stress test', 'reductions', 'reservations', 'Germany', 'Capital Requirements Regulation', '2024', 'December 2019', '2050', '1980', '2050', '2019', '1980', '2', 'three', 'two', 'One', '1', '3', 'One', '2024']
# ['interest rates', 'Deutsche Bank Research', 'Henrik Hänche', 'matter', 'podcast series', 'lineup', 'Behind the Headlines', 'episodes', 'corporations', 'institutions', 'decision makers', 'Global Head of Credit Strategy and Thematic Research', 'Jim Reid', 'kind', 'software', 'Tesla', 'series', 'Stefan Scholz', 'Headlines', 'ESG', 'Group Treasurer', 'Deutsche Post DHL', 'supply chain disruption', 'home', 'insights', 'opportunities', 'topics', 'Hänche', 'treasury', 'highlight', 'disruptor', 'part', 'discount rates', 'IT infrastructure', 'technology', 'markets', 'changes', 'Continental', 'conversation', 'steps', 'beginning', 'nobody', 'bond', 'pension obligations', 'pension obligations', 'world', 'Episode', 'Episode', 'Elon Musk', 'Podcasts', 'globalisation', 'Research website', 'Working from Home', 'pros', 'cons', 'side', 'borrowing', 'M&A', 'Google', 'Stitcher', 'Spotify', 'Apple', '10', '5', '1', '2', 'two', '10', '10']
# ['consumers', 'environment', 'revolution', 'brands', 'beliefs', 'shopping habits', 'generation', 'values', 'terms', 'image building', 'report', 'ESG', 'Luxury goods companies']
# ['economy', 'election', 'Europe', 'world', 'investors', 'course', 'interest', 'cusp', 'people', 'investors', 'hand', 'Ladies', 'gentlemen', 'man', 'session', 'attitude', 'time', 'debates', 'election', 'election', 'election', 'decisions', 'lot', 'assets', 'difference', 'wealth', 'presentations', 'beginning', 'stake', 'stake', 'discussions', 'issues', 'understatement', 'results', 'importance', 'pandemic', 'clients', 'outbreak', 'boy wonder', 'conditions', 'Agenda', 'lot', 'companies', 'euro', 'all', 'Covid', 'account surplus', 'environment', 'digitalisation', 'election', 'Mathias Döpfner', 'Bundestag', 'London', 'countries', 'economy', 'vision', 'euro', 'euro', 'engine', 'talk', 'answer', 'rules', 'state', 'German', 'return', 'everything', 'money', 'technology', 'picture', 'investments', 'investments', 'investment', 'antitrust law', 'capital market', 'planet', 'Some', 'investments', 'country', 'country', 'investment', 'problem', 'return', 'candidates', 'weaknesses', 'poll numbers', 'defense', 'redistribution', 'attack', 'situation', 'neighbours', 'chill', 'world', 'covid crisis', 'anywhere', 'action', 'doomsayer', 'finances', 'strategy', 'capital market', 'market economy', 'billions', 'way', 'gifts', 'economy', 'state capital', 'Economist', 'assets', 'assets', 'everything', 'boom', 'boom', 'boom', 'estimates', 'words', 'world market leader', 'money', 'covid', 'hand', 'Agenda 2010', 'wage restraint', 'end', 'consequences', 'assets', 'capital market', 'sustainability', 'shortage', 'market', 'problems', 'returns', 'opportunity', 'restrictions', 'opportunity', 'course', 'beginning', 'fact', 'reforms', 'export surpluses', 'president', 'shows', 'window', 'world', 'world', 'world', 'combination', 'class', 'touch', 'headline', 'countries', 'words', 'interest rates', 'investment requirement', 'strengths', 'digitalisation', 'one', 'problem', 'Germans', 'bureaucracy', 'potential', 'one', 'reform programme', 'cornerstones', 'dimensions', 'home', 'table', 'investment gap', 'upheaval', 'decisions', 'whole', 'trade', 'export nation', 'exchange rate stability', 'pandemic', 'frictions', 'phenomenon', 'supply chains', 'glocalisation', 'withdrawal', 'competition', 'competition', 'billions', 'consequences', 'strategy', 'area', 'investment location', 'legislation', 'taxes', 'individuals', 'transformation', 'capital markets union', 'poverty', 'elderly', 'prices', 'pensions', 'democracy', 'backbone', 'society', 'danger', 'thesis', 'process', 'Climate protection', 'capital goods manufacturers', 'majority decisions', 'rest', 'rule', 'all', 'treasure trove', 'United States', 'governance', 'leadership role', 'unanimity requirement', 'policy', 'answers', 'leadership role', 'strengths', 'culture', 'knowledge', 'approach', 'world', 'everyone', 'framework', 'idea', 'China', 'country', 'country', 'country', 'champions', 'phrase', 'world stage', 'entity', 'negotiating power', 'questions', 'values', 'languages', 'company', 'change', 'Many', 'Green Deal', 'plan', 'point', 'Some', 'measures', 'Democratic', 'Afghanistan', 'something', 'area', 'culture', 'bank', 'attitude', 'bank', 'scale', 'scale', 'measures', 'politics', 'Herbert Diess', 'museum', 'government', 'earth', 'both', 'ambition', 'responsibility', 'employees', 'conviction', 'work', 'lives', 'signal', 'mind', 'election campaign', 'fingers', 'heart', 'EU', 'mentality', 'Brussels', 'export boom', 'government', 'investment', 'companies', 'technology', 'change', 'opportunities', 'sustainability', 'construction', 'change', 'technology', 'goal', 'motto', 'Everyone', 'example', 'mobility solutions', 'show', 'solutions', 'sustainability knowledge', 'entrepreneurship', 'battery factory', 'entrepreneurship', 'way', 'bureaucracy', 'kind', 'government intervention', 'trains', 'cars', 'aircraft', 'permits', 'costs', 'authorities', 'structures', 'effort', 'state budget', 'part', 'proposals', 'regard', 'Fourth', 'capabilities', 'engineering expertise', 'John F. Kennedy', 'example', 'digital', 'VW', 'IAA', 'Brandenburg', ...
# ['ORRAA', 'Deutsche Bank', 'Claudio de Sanctis', 'ocean', 'communities', 'bank', 'partnership', 'innovation', 'member', 'expertise', 'bank', 'Deutsche Bank International Private Bank', 'Ocean Risk', 'DB', 'DBKGn.DB', 'NYSE', 'Resilience Action Alliance', 'XETRA', 'carbon sink', 'finance', 'action', 'International Private Bank', 'resilience', 'ORRAA', 'event', 'Banks', 'Germany', 'partnership', 'ecosystems', 'risks', 'investment', 'ecosystems', 'bank', 'ESG', 'events', 'governments', 'ocean', 'ocean', 'sustainability', 'economy', 'regions', 'weather', 'capital', 'sustainability', 'Secretary General', 'stakeholders', 'institutions', 'organisations', 'insurance companies', 'ocean', 'senior managers', 'clients', 'clients', 'bank', 'clients', 'change', 'climate risks', 'investments', 'milestone', 'impact', 'ecosystem', 'partnership', 'part', 'force', 'impact', 'world', 'ocean resilience research', 'engagement', 'collaboration', 'governance', 'risk research', 'areas', 'client engagement', 'CEO', 'society', 'heart', 'everything', 'childhood', 'much', 'environment', 'damage', 'United Nations', 'biodiversity', 'track record', 'investment processes', 'sea-level rise', 'climate', 'change', 'ocean change', 'potential', 'thought leadership', 'planet', 'mangroves', 'coral reefs', 'ways', 'Climate Action Summit', 'impacts', 'host', 'world', 'communities', 'assets', 'pace', 'sustainability strategy', 'resilience', 'Sustainability Deep Dive', 'Karen Sack', 'site', 'climate change', 'performance management', 'climate risk management', 'diversity', 'EMEA', 'business heads', 'bank experts', 'information', 'information', 'Email', 'Email', 'details', 'oceans', 'sessions', 'topics', 'Chief Executive Officer', 'presentations', 'taxonomy', 'inclusion', 'Media Relations', 'role', "United Nations' Sustainable Development Goals", 'ecosystems', 'investment', 'areas', 'benefits', 'millions', 'people', 'value', 'understanding', 'finance sector', 'ambition', 'Christian Sewing', 'Adrian Cox', 'Eva Mairinger', 'lack', 'innovation', 'way', 'Earth', '+44 20 7541 7775', '+41 44 224 5951', '2019', '2030', 'Thursday, May 20', 'US$500 million', '224', '+44', '20', '7541', '500 million', '7775', '44', '2019', '20', '5951', '2030', '+41', 'three']
# ['sustainability event', 'clients', 'bank', 'clients', 'achievements', 'sustainability front', 'staff', 'shareholders', 'report', 'Deutsche Bank', 'SDD', 'bank', 'sustainability strategy', 'Americas Christiana Riley', 'bank', 'speakers', 'event', 'agenda', 'Corporate Bank', 'society', 'society', 'topics', 'event', 'Corporate Bank', 'organisations', 'economy', 'governance', 'entities', 'details', 'Management Board member', 'reporting', 'strategy', 'heads', 'International Private Bank', 'risk management', 'topic', 'CEO', 'businesses', 'event', 'event', 'Viktoriya Brand', 'transformation', 'transition', 'Investment Bank', 'ways', 'finance', 'course', 'progress', 'presentations', 'business model', 'addition', 'plans', 'ambitions', 'regard', 'diversity', 'inclusion', 'operations', 'CFO', 'data', 'ESG', 'Gerald Podobnik', 'event', 'event', 'role', 'implementation', 'questions', 'chat function', 'start', 'Global Head of Human Resources Michael Ilgner', 'recording', 'presentations', 'Germany', 'Claudio de Sanctis', 'Lars Stoy', 'Stefan Hoops', 'Claire Coustar', 'Christian Sewing', 'Mark Fedorcik', 'speakers', 'Video recordings', 'English', 'German', 'bank', 'event', 'agenda items', 'presentations', 'sustainability strategy', 'areas', 'sustainability activities', 'forces', 'initiators', 'course', 'Group Enterprise Risk Management', 'Head of Group Sustainability', 'CRO', 'Chris Jaques', 'Jörg Eigendorf', 'Monday, May 24', '24']

# %%
sentiment{'positive':0, 'negative':0}
for key, value in news_json.items():
    print(value['sentiment'])
# Out:
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# negative
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# negative
# positive
# positive
# positive
# positive
# positive
# positive
# negative
# positive
# positive
# positive
# positive
# negative
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# negative
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# negative
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# negative
# negative
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# neutral
# positive
# negative
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# negative
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# negative
# negative
# positive
# positive
# negative
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# negative
# positive
# negative
# positive
# positive
# positive
# negative
# positive
# positive
# positive
# negative
# positive
# positive
# positive
# negative
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# neutral
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# negative
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# neutral
# positive
# negative
# positive
# negative
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# negative
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# negative
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# neutral
# positive
# negative
# positive
# positive
# negative
# positive
# positive
# neutral
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# negative
# positive
# positive
# positive
# positive
# negative
# positive
# positive
# positive
# negative
# positive
# negative
# positive
# positive
# positive
# positive
# positive
# negative
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# negative
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# negative
# positive
# negative
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# positive
# negative
# positive
# positive
# positive
# negative
# positive
# positive
